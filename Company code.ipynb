# %%
import pandas as pd
import re
import numpy as np
import gc
from fuzzywuzzy import fuzz

# %%
df_contribuion = pd.read_csv('data/contribution_processed.csv')
df_companies = pd.read_csv('data/ma-companies-on-linkedin.csv', sep = ';')

# %%
companies_list = df_companies['Company name'].unique()

# %%
employer_list = df_contribuion['Employer'].unique()

# %%
employer_list.shape
# Out:
# (17338,)

# %%
companies_list.shape
# Out:
# (67306,)

# %%
def clean_text(text):
    '''
    Remove special charecters, numbers
    Return lower case alphabet charecters only
    '''
    text = str(text).lower()
    text = re.sub('[^A-Za-z]+', '', text)
    return text

# %%
companies_list_clean = np.array([clean_text(x) for x in companies_list.copy()])

# %%
employer_list_clean = np.array([clean_text(x) for x in employer_list.copy()])

# %%
# MATCHING

# %%
match = []
companies_list_clean = companies_list_clean.astype('O')
employer_list_clean = employer_list_clean.astype('O')

for employer in employer_list_clean:
    for company in companies_list_clean:
        if fuzz.ratio(employer, company) >= 85:
            match.append(employer)

# %%
match_set = set(match)

# %%
len(match_set)
# Out:
# 5337

# %%
match_set
# Out:
# {'obrienassociates',
#  'fatherbillsmainspringhouse',
#  'schawbeltechnologiesllc',
#  'westfieldbank',
#  'messingerinsurance',
#  'bristolcountysavingsbank',
#  'unitedmethodistchurch',
#  'harvardbuisnessschool',
#  'jrichsolutions',
#  'bostonportfolioadvisers',
#  'commwealthofmass',
#  'finepointcapital',
#  'bioenergyinternational',
#  'corcoranandjennison',
#  'realestate',
#  'maaps',
#  'aacconsulting',
#  'vercpartnership',
#  'bluehillcemetery',
#  'bertucis',
#  'masslegalassistancecorporation',
#  'stbernadetteschool',
#  'gbelectricalservices',
#  'tarlowbreedhartrodgers',
#  'lawrencecommunityworks',
#  'confluentsurgical',
#  'greaterhaverhillchamberofcommerce',
#  'wayfair',
#  'independentcontractor',
#  'tremblaybus',
#  'harvarduniversity',
#  'nixonpeabody',
#  'careerpoint',
#  'prodevelopmentgroup',
#  'borislowinsurance',
#  'agency',
#  'berkshirehealthsystems',
#  'kevinpmartinassociates',
#  'vesonnautical',
#  'dearbornacademy',
#  'haaphousing',
#  'eastforkgroupllc',
#  'brocktonneighborhoodhealthcenter',
#  'uaspire',
#  'takedapharmaceuticals',
#  'woburnpolicedept',
#  'mlstrategiesllc',
#  'ermstrategies',
#  'newenglandurologyassociates',
#  'sagesystems',
#  'rismaninsurance',
#  'jjmaterials',
#  'hampdencarefacilityinc',
#  'lynchassociation',
#  'citywidecontracting',
#  'internationallight',
#  'centralcatholichignschool',
#  'flanneryrealestate',
#  'easternfisheries',
#  'trombleyassociates',
#  'lucysrestaurant',
#  'projectrightinc',
#  'indiahillmusic',
#  'bostonseniorhomecare',
#  'publicconsultinggroup',
#  'actionam',
#  'maxwellhealth',
#  'epm',
#  'pittsfieldpublicschools',
#  'partnershealth',
#  'stmaryscreditunion',
#  'massachusetts',
#  'marcottefordsalesinc',
#  'eisenbergconsulting',
#  'redtreeproductionsinc',
#  'shorelighteducation',
#  'omninavitas',
#  'townofframingham',
#  'thehollandcompanies',
#  'suezenergynorthamerica',
#  'merrimackvalleydistributor',
#  'newenglandschoolofacupuncture',
#  'homebuildersassociationofwesternmassachusetts',
#  'williamjamescollege',
#  'centerforhumandevelopmentinc',
#  'jancodevelopment',
#  'wts',
#  'msamortgage',
#  'costantinorichardsrizzollp',
#  'binkeezforcomfort',
#  'perkinsschoolfortheblind',
#  'shieldshealthcare',
#  'leaderbank',
#  'hawkeyefence',
#  'davismaldagostinepc',
#  'massassociationofhealthunderwriters',
#  'rrindustriesinc',
#  'raytheon',
#  'normandyrealestatepartners',
#  'aptushealth',
#  'armstrongadvisorygroup',
#  'silvustechnologies',
#  'polarbeverage',
#  'lebelassociates',
#  'designcommunicationsltd',
#  'coryandassociates',
#  'thorntonlawfimllp',
#  'rizzoassociates',
#  'alnylampharmaceuticals',
#  'coghlincompaniesinc',
#  'caseassociates',
#  'bostonpubliclibrary',
#  'fisherbusco',
#  'fulfillmentamerica',
#  'barrowsinsurance',
#  'familyserviceofgreaterboston',
#  'cityofbostoncu',
#  'sbventures',
#  'lincolnlaboratories',
#  'merrimackvalleyinsurance',
#  'parsonsbrinckerhoff',
#  'internationalinstituteofnewengland',
#  'poweroptions',
#  'beaconsservices',
#  'delanyassociates',
#  'dartmouthpublicschools',
#  'massmedicalassociates',
#  'vargasvargasinsurance',
#  'northeasthomeandenergy',
#  'sunovionpharmaceuticals',
#  'bostonuniversityschooloflaw',
#  'tfassociates',
#  'nerconstruction',
#  'richeywoodworking',
#  'vitaorgsolutions',
#  'fhperrybuilders',
#  'cloudkidstudios',
#  'frequencytherapeutics',
#  'hvac',
#  'morseinsagencyinc',
#  'rubywine',
#  'quirkautodealersinc',
#  'entrepreneurshipforall',
#  'columbiatech',
#  'converse',
#  'ashmontgrille',
#  'lawoffficeofmichaeldash',
#  'tesaroinc',
#  'syndaxpharmaceuticals',
#  'tarlowbreedhartrogerspc',
#  'everettfiredept',
#  'ecammnetwork',
#  'zfoundation',
#  'maldenpublicschools',
#  'jackconwaycompanyinc',
#  'wgbh',
#  'acronis',
#  'danversportyachtclub',
#  'sorellebakerycafe',
#  'sgp',
#  'westwoodpediatrics',
#  'southshoreelderservicesinc',
#  'deccoinc',
#  'rainbowballoonsinc',
#  'cdservices',
#  'corribrestaurant',
#  'tec',
#  'dartmouthbuildingsupply',
#  'corryassociatesllc',
#  'lowellregionaltransitauth',
#  'diversifiedfunding',
#  'cabotwealthmanangementinc',
#  'accunetsolutions',
#  'associationofbehaviorialhealth',
#  'enernoc',
#  'commonwealthofmass',
#  'meyersbrotheskalicka',
#  'sederchandler',
#  'keystonepartners',
#  'bmzdevelopmentllc',
#  'cambridgeassociatesllc',
#  'millstores',
#  'johnstait',
#  'trinityfinancial',
#  'panoramaeducation',
#  'beaconstrategiesgroup',
#  'macenterforhealthinformationandanalysis',
#  'massservice',
#  'nextworthsolutions',
#  'commonwealthcorporation',
#  'polarbeverages',
#  'directfinancecorp',
#  'morphotrustusa',
#  'delsaenterprises',
#  'allaccessphysicaltherapy',
#  'mtauburnhospital',
#  'umassmedicalschool',
#  'novus',
#  'linchrishotelcorporation',
#  'newenglandpetimaging',
#  'hayespump',
#  'davidking',
#  'sierrayanezlawllc',
#  'rklesolutionsllc',
#  'cambridgeassociates',
#  'bostonlandmarksorchestra',
#  'kesslermcguinnessassociatesllc',
#  'carrollcenterfortheblind',
#  'thecottingschool',
#  'bealsassociates',
#  'bristolcountychamberofcommerce',
#  'cityrealtygroup',
#  'williamsbuildingcompany',
#  'marraffaandassociates',
#  'resourceconnection',
#  'bostonhealthcareforthehomeless',
#  'donaghuebarrettsingal',
#  'gehealthcare',
#  'templebethavodah',
#  'townofsandwich',
#  'rancoenterprisesinc',
#  'muellerservices',
#  'winokurserkeyrosenbergpc',
#  'jinteractive',
#  'masssocietyforthepreventionofcrueltytochildren',
#  'brianhickeyassoc',
#  'greaterashmontmainstreet',
#  'hallassociates',
#  'leadingedgerealestate',
#  'leffoundation',
#  'georgetownbank',
#  'firstelectricmotorservice',
#  'covingtonassociates',
#  'mitpeerengage',
#  'richardsoninsurance',
#  'wgbheducationalfoundation',
#  'perkinsanctil',
#  'fitchburgstateuniversity',
#  'hyannismarina',
#  'realestateassociates',
#  'mcbr',
#  'meehanboyleblackandbogdanowpc',
#  'shadisrestaurant',
#  'clinicalsupportoptions',
#  'biobridges',
#  'crawfordcommunications',
#  'dicernapharmaceuticals',
#  'gallantinsuranceagency',
#  'sedarchandler',
#  'dunkinbrandsinc',
#  'churchhillconstruction',
#  'breurco',
#  'americanmeteorologicalsociety',
#  'mentor',
#  'oldetownerealestate',
#  'wingatehealthcare',
#  'boyleshaughnessylaw',
#  'collorallp',
#  'massaudobon',
#  'dayassociates',
#  'massachusettstrialcourt',
#  'thecopleygroup',
#  'bostonluxuryproperties',
#  'bostonpic',
#  'birchtreecapital',
#  'associatedindustriesofmassachusetts',
#  'adasolutionsinc',
#  'corwincorwinllp',
#  'cetrullollp',
#  'sarochiropractics',
#  'collegebounddorchester',
#  'morphotrust',
#  'southbaycommunityservices',
#  'debrasnaturalgourmet',
#  'communitycatalyst',
#  'valleyrealestate',
#  'townofraynham',
#  'cohenpartners',
#  'amex',
#  'politicalresearchassociates',
#  'primaceainc',
#  'massachusettslegalassistancecorp',
#  'commonwealthpsychologyassociates',
#  'digitas',
#  'cdmsmith',
#  'currentinstructionllc',
#  'fenwaycommunityhealthcenter',
#  'thedaviscompanies',
#  'powerproducts',
#  'tangierinorestaurant',
#  'centralmasshousingalliance',
#  'interactioninstituteforsocialchange',
#  'corrigancommunications',
#  'nuacinvestmentmanagement',
#  'manninggrossmassenburgllp',
#  'thesuffolkgroup',
#  'privateindustrycouncil',
#  'oneillproperties',
#  'publicconsultinggroupinc',
#  'townofwatertown',
#  'analogiccorporation',
#  'americancapitalenergy',
#  'atlasinvestmentgroup',
#  'stonehillcollege',
#  'edwardmkennedyinstitutefortheussenate',
#  'bluemetalarchitects',
#  'salemstateuniversity',
#  'alvianiassociates',
#  'learningprepschool',
#  'erabostonrealestategroup',
#  'excellacademycharterschool',
#  'thecommunitybuildersinc',
#  'terranoveassociates',
#  'gjwconstruction',
#  'loomissaylescompanyllc',
#  'frpublicschools',
#  'jvs',
#  'perkinelmer',
#  'jkarammanagement',
#  'richardwreidelectricalco',
#  'whistlersinn',
#  'applustechnologies',
#  'thehudsongroup',
#  'mainstreet',
#  'sherinlodgenllp',
#  'anthonyngiamberardino',
#  'bostonianconstructionservicesllc',
#  'nefwc',
#  'maniongaynormaningllp',
#  'syntaxpharmaceuticalsinc',
#  'thecommonwealthofmassachusetts',
#  'ryandevelopement',
#  'foderaconstructionco',
#  'stmicroelectronics',
#  'alfalfafarmwinery',
#  'hemenwaybarnes',
#  'columbiaconstructionco',
#  'youthphilanthropyconnect',
#  'longfellowrealestatepartnersllc',
#  'cignacorporation',
#  'paoliniassociates',
#  'mathasvineyardhospital',
#  'starwood',
#  'lpcontracting',
#  'silentspringinstitute',
#  'conwayinsuranceagency',
#  'wherbertgoodickinc',
#  'newenglandclaimsassociation',
#  'americanexpress',
#  'capitolgroup',
#  'princetonreview',
#  'equalexchange',
#  'commonwealthrealestate',
#  'themalloygroupinc',
#  'abcdisposal',
#  'amicainsurance',
#  'lakevillecountryclub',
#  'dcconsultingservices',
#  'suburbanlawnsprinkler',
#  'conwaycahillbrodeurfuneralhome',
#  'buyersbrokersllc',
#  'harmonyhealthcareinternational',
#  'mortonhospital',
#  'peterpanbuslines',
#  'millenniumpartners',
#  'fieldscornerbusinessbob',
#  'morseinsuranceagency',
#  'rosemonttrustllc',
#  'mansfieldbeautyschools',
#  'emersonhospital',
#  'murphyassociates',
#  'stephaniesonnewbury',
#  'kaneconstruction',
#  'amherstcinema',
#  'mayburymaterialhandling',
#  'partnersinhealth',
#  'piersparksailingcenter',
#  'davismalmdagostine',
#  'townofplymouth',
#  'thegandaracenter',
#  'waldenbehavioralcare',
#  'middlesexsheriff',
#  'massrehabcomission',
#  'fallriverpawnbroker',
#  'cantinaconsultinginc',
#  'princetonproperties',
#  'realestateco',
#  'hillcresteducationcenter',
#  'bcac',
#  'thesacrocompanies',
#  'beaconhillstaffing',
#  'gordoncollegge',
#  'retailersassocofmass',
#  'maassociationofschoolcommittees',
#  'riversidecommunitycare',
#  'mpaa',
#  'sallyfitchllp',
#  'lrcassociates',
#  'massachusettswomenspoliticalcaucus',
#  'barringtonstageco',
#  'childrenshospital',
#  'townofbarnstable',
#  'samaritans',
#  'pac',
#  'ferriternewardscobborodophelepc',
#  'mitlincolnlaboratories',
#  'charlesbankapartments',
#  'homeforlittlewanderers',
#  'amermeteorologicalsociety',
#  'morseinsurance',
#  'citizenshousingandplanningassociation',
#  'raskybaerleinstrategiccommunicationsinc',
#  'laheyhospitalandmedicalcenter',
#  'mdbeautysalon',
#  'meditech',
#  'healthresourcesinacton',
#  'cityofboston',
#  'mtec',
#  'lbcboston',
#  'utec',
#  'progresssoftware',
#  'aftmassachusetts',
#  'philjohnstonassociates',
#  'cityofquincyma',
#  'solomonmccown',
#  'patriotenergygroup',
#  'cra',
#  'thelongfellowclubs',
#  'primelandscaping',
#  'sentenialsystems',
#  'cityofnorthamptonma',
#  'crystalengineering',
#  'oconnordrewpc',
#  'zumix',
#  'norfolkcounty',
#  'fullcircletechnologies',
#  'heatherhillcountryclub',
#  'newenglandicecreamcorp',
#  'wcrib',
#  'newenglandcleanenergy',
#  'capecodfivecentssavingsbank',
#  'healthnewengland',
#  'bostonspinegroup',
#  'bostonfinancialinvestmentmanagement',
#  'townofnorthattleborough',
#  'verccarrental',
#  'commonwealthofmassa',
#  'caldwellbanker',
#  'lennoxinternational',
#  'northeastcenterforyouthandfamilies',
#  'homecityhousing',
#  'doctorfranklinperkinsschool',
#  'perlerarealestateinc',
#  'shawmutdesignconstruction',
#  'cplanhealthresourcesinaction',
#  'cityrealty',
#  'stewardhealthcare',
#  'bigjimsautobody',
#  'doulasokunassociates',
#  'burkedistributingcorporation',
#  'mendesmedicalassociates',
#  'energymanagement',
#  'zerovfx',
#  'jrsweeneyinsurance',
#  'fernwoodadvisorsinc',
#  'attnewengland',
#  'clarkeschool',
#  'bennettbelfort',
#  'humanscale',
#  'aawillmaterialscorp',
#  'townofabington',
#  'fsg',
#  'lambertsrainbowfruit',
#  'moneris',
#  'pinehills',
#  'optilineenterprisesllc',
#  'citizensforcitizensinc',
#  'northernconstructionllc',
#  'costellodismantlingco',
#  'sociallawlibrary',
#  'horsleywittengroup',
#  'patriotcontractingservicesllc',
#  'efg',
#  'qualitybeverageslp',
#  'envisionbank',
#  'allcomcreditunion',
#  'massachusettsinstituteoftechnology',
#  'plymouthchamberofcommerce',
#  'rcapitolinc',
#  'goldsteinlee',
#  'thecommunitybuilders',
#  'mbcr',
#  'acellaconstructioncorporation',
#  'greeneliteservices',
#  'unionofconcernedscientists',
#  'rehab',
#  'cotuitliquors',
#  'amconstruction',
#  'lathamcentersinc',
#  'dalygroup',
#  'linquestcorporation',
#  'phoenixinc',
#  'squareone',
#  'memberspluscreditunion',
#  'educationdevelomentcenteredc',
#  'osullivanassociates',
#  'tuftsuniversity',
#  'douglasfuneralhome',
#  'holyokegasandelectric',
#  'franciscanhospitalforchildren',
#  'brooklinepublicschools',
#  'acluofmassachusetts',
#  'jacobsvelellakerr',
#  'coutomanagementgroup',
#  'mit',
#  'bostoniangroup',
#  'raskypartnersinc',
#  'luceyinsuranceagencyinc',
#  'russiancommunityass',
#  'staddspecialist',
#  'lagonetautobodyandframe',
#  'everettpublicschools',
#  'bostonchildrenshospital',
#  'commonwealthma',
#  'thecommunitygroup',
#  'bealsthomasinc',
#  'contractor',
#  'bostonschoolsfunds',
#  'townofavon',
#  'kennedydonovancenter',
#  'lexingtonpublicschools',
#  'homestartinc',
#  'serlinehaleyllp',
#  'teamstersunionlocal',
#  'firstrealtymanagement',
#  'saltonstallco',
#  'northcentralworkforceinvestmentboard',
#  'quirkautodealers',
#  'rosalespartners',
#  'stjeanscreditunion',
#  'cryogenicinstituteofnewenglandinc',
#  'independentagent',
#  'marrrealestate',
#  'phillipsmanornursinghome',
#  'cooleymanionjones',
#  'phan',
#  'byrneandersonllp',
#  'simmonscollege',
#  'sunpower',
#  'commonwealthcare',
#  'dinosaurcapitalpartners',
#  'thevallegroup',
#  'globeliquors',
#  'neitzrealestate',
#  'kushgroove',
#  'marshfieldpublicschools',
#  'greaterspringfieldconventionandvisitorsbureauinc',
#  'capstickassociates',
#  'philipshealthcare',
#  'athenahealthcare',
#  'atruishealth',
#  'northbridgepartners',
#  'bristolcountydistrictattorney',
#  'sharonassociates',
#  'dowlinghouy',
#  'beckercollege',
#  'burkeelectricinc',
#  'soperlandscaping',
#  'massachusettsattorneygeneralsoffice',
#  'mariancourtcollege',
#  'windhamcapital',
#  'baesystems',
#  'lawofficesofcarmendurso',
#  'dataguidecable',
#  'cspace',
#  'thecolvestgroupllc',
#  'commofmasshouseofrepresentatives',
#  'giacomosrestaurant',
#  'hubtechnicalservicesllc',
#  'massachusettsbankersassociation',
#  'southcovecommunityhealthcenter',
#  'financeboston',
#  'harmoniclabsolutions',
#  'thevanngroup',
#  'rwholmesrealty',
#  'regencytransportationinc',
#  'autismsprinter',
#  'cornerstonerealestate',
#  'edtech',
#  'harpoonbrewery',
#  'intexsolutions',
#  'chesnuthillrealty',
#  'orsiniconsulting',
#  'thesylviagroup',
#  'falitebrothers',
#  'combieshanson',
#  'resnicbeauregardwaitedriscoll',
#  'empowerher',
#  'vendettimotors',
#  'flacccooperative',
#  'gregoryandassociates',
#  'jobsforthefuture',
#  'burrbrothersboatsinc',
#  'eaeducation',
#  'norfolkhardware',
#  'lawrencememorialhospital',
#  'fidelityinvestment',
#  'sentryford',
#  'virgilioconstruction',
#  'union',
#  'thehotelnorthampton',
#  'jrigroupllc',
#  'azinvestmentsllc',
#  'johnmcglynn',
#  'santanasrestaurant',
#  'uawlocal',
#  'africancommunityeducation',
#  'pjaadvertising',
#  'earthsource',
#  'rubertoisraelweinerpc',
#  'cruzcompanies',
#  'chmventures',
#  'bscgroup',
#  'landstrategies',
#  'mannorchards',
#  'bostonafterschoolandbeyond',
#  'copydirect',
#  'achivarestaurant',
#  'jrsproperties',
#  'saintsmemorialmedicalcenter',
#  'theedinburgcenter',
#  'cityonahillcharterschool',
#  'considineandfureyllp',
#  'sauconyinc',
#  'westendhouse',
#  'biogen',
#  'seniorassociate',
#  'longpondphysicaltherapy',
#  'communityadvocate',
#  'theassociationforcommunityliving',
#  'rmrealty',
#  'crystalfinancialllc',
#  'osramsylvaniainc',
#  'provencherinsurance',
#  'baystatephysicaltherapy',
#  'costelloinsurance',
#  'spiritofspringfieldinc',
#  'burnhamrosengroup',
#  'burkhartpizzanelly',
#  'quinnandmorrispc',
#  'dermodycleaners',
#  'harveysons',
#  'stewardhealthcaresystem',
#  'cchealthcare',
#  'haleyassociates',
#  'cityyear',
#  'worcester',
#  'buchananassociates',
#  'montachusettopportunitycouncil',
#  'mentalhealthassociationofgreaterlowell',
#  'pertistragegies',
#  'dohertyciechanowskidugancannon',
#  'aidsactioncommittee',
#  'colantonioinc',
#  'nicholaeffarchitecture',
#  'stonehamford',
#  'suffolkcountysheriffs',
#  'africancommunityeducationprogram',
#  'bigsisterassociationofgreaterboston',
#  'magellanjets',
#  'bridgewaterstateuniveristy',
#  'quirkautosales',
#  'brooklineperiodontal',
#  'curriculumassociates',
#  'miltonacademy',
#  'commonwealthcapitalcorp',
#  'somervillepublicschools',
#  'massachusettsassociationformentalhealth',
#  'remaxexecutiverealty',
#  'selfstonoverfarm',
#  'newenglandcenterforarttechnology',
#  'gmcstrategies',
#  'vinfen',
#  'enelgreenpowernorthamerica',
#  'amesburypsychologicalcenterinc',
#  'allianceofmassachusettsymcas',
#  'nigropettepitlucas',
#  'axiainsuranceagency',
#  'welchforbes',
#  'southshorementalhealth',
#  'jmarshallassociates',
#  'salarycom',
#  'kileycosgroveeisenbergkiley',
#  'pillpack',
#  'hughco',
#  'wesconinc',
#  'escofnewengland',
#  'springfieldtechcommunitycollege',
#  'kltassociatesinc',
#  'ferrierscobboandrodophelepc',
#  'gannonconstruction',
#  'providentbank',
#  'draperlaboratory',
#  'commonweathofmassachusetts',
#  'lombardos',
#  'theforsythinstitute',
#  'newenglandinstituteofart',
#  'middleborofamilydental',
#  'cvscorporation',
#  'easthorizoninvestments',
#  'wordsmithpress',
#  'bkwpartners',
#  'mohrmanassociates',
#  'hammondresidentialrealty',
#  'pentucketmedicalassociates',
#  'horizonbeverageco',
#  'cosgroveeisenberkiley',
#  'eastcambridgesavingsbank',
#  'rfwhiteassociates',
#  'longfellowdesignbuild',
#  'vanderweilengineers',
#  'beaconhotel',
#  'mjrconsulting',
#  'medpayinc',
#  'lubinmeyer',
#  'quincyasianresourcesinc',
#  'rsasecurityllc',
#  'commonwealthradiologyassociates',
#  'dempseyinsuranceagency',
#  'skyrestaurant',
#  'financialrecoverytechnologiesp',
#  'williamryanassociates',
#  'northruprealtors',
#  'balbonicommunicationsgroupllc',
#  'headsupirrigation',
#  'chateaurestaurant',
#  'mirracompany',
#  'theamfund',
#  'jarabekcharitablefoundation',
#  'sallyfitch',
#  'theactiongroup',
#  'mcphailassociatesinc',
#  'healthcarewithoutwalls',
#  'brookhavenatlexington',
#  'massachusettslodgingassociation',
#  'perfusionsupplyservicesinc',
#  'villaroseresturant',
#  'castechnologiesinc',
#  'massachusettsparentsunited',
#  'publicrelations',
#  'nhp',
#  'lopesfuneralhome',
#  'massachusettshealthhospitalassociation',
#  'wequassettinn',
#  'addisongroup',
#  'landmarkmanagementsolutions',
#  'couselbutkusjessonllp',
#  'friedmansuvallesalomoncpapc',
#  'bostoncenterless',
#  'murphydonahuepartners',
#  'whitmanhomes',
#  'williamcoyneassociates',
#  'mountholyokecollege',
#  'communityhealthlink',
#  'integratedpartners',
#  'tcamllc',
#  'mcompany',
#  'mswalker',
#  'mswalkerco',
#  'mirakproperties',
#  'segalryanbrennanpc',
#  'segalryanbrennan',
#  'charlesconstruction',
#  'lowellcommunityhealthctr',
#  'newenglandpowergenerationassociates',
#  'philrichardinsurance',
#  'crystalspringsinc',
#  'landmarkrealty',
#  'cardinalcushingcenters',
#  'commodorebuilders',
#  'mulkerinrealty',
#  'radiushealthcare',
#  'readingcooperativebank',
#  'wellscollege',
#  'lawofficesofpetertclarkpc',
#  'bostonfire',
#  'mahighwaydept',
#  'gagliarducciconstruction',
#  'heliescompany',
#  'keeganwirlinllp',
#  'gavinfoundation',
#  'kenneysames',
#  'acraneconstructioncompany',
#  'maassocofhealthplans',
#  'btgenvironmental',
#  'massgeneralhospital',
#  'nuciforolawgroupllc',
#  'caronassociates',
#  'veristat',
#  'theestevesgroup',
#  'teagnoconstructioninc',
#  'peabodyarnold',
#  'tooleinsurance',
#  'donovanhatemllp',
#  'harvardlawschool',
#  'sunsteinkannmurphytimbersllp',
#  'massafterschoolpartnership',
#  'easternbank',
#  'clinicalsupportoption',
#  'gilbertandrenton',
#  'darrylescornerbarkitchen',
#  'miniluxe',
#  'thecollaborativecompanies',
#  'csagraphics',
#  'tarvisrealtyllc',
#  'renaissanceco',
#  'gateshealthcare',
#  'massdevelopment',
#  'laheyclinicck',
#  'traggorthcompanies',
#  'signetelectronics',
#  'kimballfarms',
#  'lrassociates',
#  'brocktonhousingauthority',
#  'massachusettsattorneygeneral',
#  'chapdelainelawoffice',
#  'firstrealtymanagementco',
#  'magellandiagnostics',
#  'peabodyproperties',
#  'conroytalentassociates',
#  'retailmanagementanddevelopment',
#  'penobscotinvestmentmanagement',
#  'accutronicsinc',
#  'mci',
#  'fairfieldinn',
#  'harvardbusinessschool',
#  'concordfoods',
#  'songconsulting',
#  'lajoieinvestigations',
#  'ebbetsfieldcapitalmanagement',
#  'bostonmutual',
#  'cardinalcushingcentersinc',
#  'brighamandwomensfaulknerhospitalhospital',
#  'nouriaenergycorporation',
#  'shirepharmaceuticals',
#  'turboconsulting',
#  'ssecuritycorporation',
#  'quinnmorrispc',
#  'hooverrealtytrust',
#  'simondssaw',
#  'bcnc',
#  'merrimackvalleydistributing',
#  'autopartinternational',
#  'colonyfoods',
#  'waterfrontpropertiesllc',
#  'womanssheltercompaeras',
#  'rizemassachusetts',
#  'witmanpropertiesinc',
#  'concurtechnologies',
#  'folanwaterproofingcoinc',
#  'whippsinc',
#  'lawofficeskevinpatrickseaver',
#  'ymcagreaterboston',
#  'brodyhardoonperkinskesten',
#  'cityofattleboro',
#  'tecinc',
#  'pcom',
#  'isaacsonmiller',
#  'woodsholegolfclub',
#  'worceterpolytechnicinstitute',
#  'sylviagroup',
#  'educationdevelopmentcenter',
#  'berkshirehealthcaresystems',
#  'ris',
#  'formlabs',
#  'bostoncollegecenterforcorporatecitizenship',
#  'safewaytransportation',
#  'cityofbostoncreditunion',
#  'watertownpublicschools',
#  'keeganwerlinllp',
#  'mah',
#  'rossinsuranceagencyinc',
#  'serlinhaleyassociates',
#  'chestnuthillrealty',
#  'newenglandlawboston',
#  'girardfinancialgroup',
#  'caronconsulting',
#  'blueoxrestaurant',
#  'jmpaintconstruction',
#  'multiculturalhomecare',
#  'holdingsteenrealestate',
#  'srweinerassociatesinc',
#  'igemfoundation',
#  'hollandconstruction',
#  'printsynergysolutions',
#  'lawofficesofbrianmoran',
#  'raskypartners',
#  'jaycashmaninc',
#  'erconinc',
#  'houghtonmifflinharcout',
#  'familychiropractic',
#  'lawofficeofmichaelzaim',
#  'goodwinprocter',
#  'brandeisuniversityinternationalbusinessschool',
#  'marguliesperruzziarchitects',
#  'bostonrealtyadvisors',
#  'kellercompany',
#  'bostonpublichealthcommission',
#  'ferriterandferriterllc',
#  'oldneighborhoodfoods',
#  'policeofficer',
#  'recoveringchanpionsinc',
#  'nashobaschooldistrict',
#  'bbconstructionremodeling',
#  'showabostoninstitute',
#  'baystaehealth',
#  'priorityparking',
#  'avbconstruction',
#  'greencambridge',
#  'eastbostonsocialcenters',
#  'riceheardbigelowinc',
#  'edwardstreetdaycarecenter',
#  'newyorkinstituteoftechnology',
#  'conte',
#  'ambri',
#  'kelleherandsadowsky',
#  'architect',
#  'bowdoingenevamainstreets',
#  'mwraadvisoryboard',
#  'atlantischarterschool',
#  'northshorepatentspc',
#  'morrislawoffice',
#  'newenglandcenter',
#  'massachusettscollegeofartanddesign',
#  'nfib',
#  'usvisothebysinternationalrealty',
#  'atlanticcharterschool',
#  'williameryanassociates',
#  'prosperitycandle',
#  'chineseprogressiveassociation',
#  'solomonmccowan',
#  'melloconstruction',
#  'ferriterscoboorodophelepc',
#  'landtechconsultants',
#  'banecaremanagement',
#  'rbadvisory',
#  'coughlinbetkellp',
#  'highlandliquors',
#  'northeastutilities',
#  'wilsonfarm',
#  'mpha',
#  'dailytable',
#  'metropolitanbostonhousingpartnershipinc',
#  'greenmeadowfarms',
#  'klkenterprises',
#  'mgnassociates',
#  'foleyhoagllp',
#  'kendallhotel',
#  'baublesinc',
#  'commonweatlhofmassachusetts',
#  'sanofigenzyme',
#  'theesplanadeassociation',
#  'massachusettsbiotechnologycouncil',
#  'middlesexsavingsbank',
#  'rightturn',
#  'springbankpharmaceuticals',
#  'tarlowbreedhartrodgerspc',
#  'thorntonlawfirmllc',
#  'galanteinsurance',
#  'cpacconstruction',
#  'eastcoastseafood',
#  'thelenoxhotel',
#  'macgraycorporation',
#  'kingbishop',
#  'gfindustries',
#  'oneilconsulting',
#  'elpelantaqueria',
#  'metropolitanuniformlinen',
#  'admanagementcorp',
#  'eastonpublicschools',
#  'fsquaredinvestmentsinc',
#  'michelassociates',
#  'thearchitecturalteam',
#  'eyehealthassociates',
#  'leahyhealth',
#  'winthrop',
#  'prellwitzchilinskiassociates',
#  'thecateredaffair',
#  'mitrecorporation',
#  'baesisinc',
#  'antoniosrestaurant',
#  'zamirchoraleofboston',
#  'oceanspraycranberriesinc',
#  'peopleinc',
#  'massachusettsstatepolice',
#  'plannedparenthoodofmassachusetts',
#  'matechcorp',
#  'holyokecreditunion',
#  'chamberofcommerce',
#  'falloncompany',
#  ...}

# %%
df_contribuion['Employer_clean'] = df_contribuion['Employer'].apply(clean_text)

# %%
df_companies['Company_clean'] = df_companies['Company name'].apply(clean_text)

# %%
def company_search(name):
    return name in match_set

# %%
df_contribuion['Industry_new'] = df_contribuion['Employer_clean'].apply(company_search)

# %%
df_contribuion['Industry_new'].value_counts()
# Out:
# False    95910
# True     22551
# Name: Industry_new, dtype: int64

# %%
# New trial

# %%
match_set
# Out:
# {'obrienassociates',
#  'fatherbillsmainspringhouse',
#  'schawbeltechnologiesllc',
#  'westfieldbank',
#  'messingerinsurance',
#  'bristolcountysavingsbank',
#  'unitedmethodistchurch',
#  'harvardbuisnessschool',
#  'jrichsolutions',
#  'bostonportfolioadvisers',
#  'commwealthofmass',
#  'finepointcapital',
#  'bioenergyinternational',
#  'corcoranandjennison',
#  'realestate',
#  'maaps',
#  'aacconsulting',
#  'vercpartnership',
#  'bluehillcemetery',
#  'bertucis',
#  'masslegalassistancecorporation',
#  'stbernadetteschool',
#  'gbelectricalservices',
#  'tarlowbreedhartrodgers',
#  'lawrencecommunityworks',
#  'confluentsurgical',
#  'greaterhaverhillchamberofcommerce',
#  'wayfair',
#  'independentcontractor',
#  'tremblaybus',
#  'harvarduniversity',
#  'nixonpeabody',
#  'careerpoint',
#  'prodevelopmentgroup',
#  'borislowinsurance',
#  'agency',
#  'berkshirehealthsystems',
#  'kevinpmartinassociates',
#  'vesonnautical',
#  'dearbornacademy',
#  'haaphousing',
#  'eastforkgroupllc',
#  'brocktonneighborhoodhealthcenter',
#  'uaspire',
#  'takedapharmaceuticals',
#  'woburnpolicedept',
#  'mlstrategiesllc',
#  'ermstrategies',
#  'newenglandurologyassociates',
#  'sagesystems',
#  'rismaninsurance',
#  'jjmaterials',
#  'hampdencarefacilityinc',
#  'lynchassociation',
#  'citywidecontracting',
#  'internationallight',
#  'centralcatholichignschool',
#  'flanneryrealestate',
#  'easternfisheries',
#  'trombleyassociates',
#  'lucysrestaurant',
#  'projectrightinc',
#  'indiahillmusic',
#  'bostonseniorhomecare',
#  'publicconsultinggroup',
#  'actionam',
#  'maxwellhealth',
#  'epm',
#  'pittsfieldpublicschools',
#  'partnershealth',
#  'stmaryscreditunion',
#  'massachusetts',
#  'marcottefordsalesinc',
#  'eisenbergconsulting',
#  'redtreeproductionsinc',
#  'shorelighteducation',
#  'omninavitas',
#  'townofframingham',
#  'thehollandcompanies',
#  'suezenergynorthamerica',
#  'merrimackvalleydistributor',
#  'newenglandschoolofacupuncture',
#  'homebuildersassociationofwesternmassachusetts',
#  'williamjamescollege',
#  'centerforhumandevelopmentinc',
#  'jancodevelopment',
#  'wts',
#  'msamortgage',
#  'costantinorichardsrizzollp',
#  'binkeezforcomfort',
#  'perkinsschoolfortheblind',
#  'shieldshealthcare',
#  'leaderbank',
#  'hawkeyefence',
#  'davismaldagostinepc',
#  'massassociationofhealthunderwriters',
#  'rrindustriesinc',
#  'raytheon',
#  'normandyrealestatepartners',
#  'aptushealth',
#  'armstrongadvisorygroup',
#  'silvustechnologies',
#  'polarbeverage',
#  'lebelassociates',
#  'designcommunicationsltd',
#  'coryandassociates',
#  'thorntonlawfimllp',
#  'rizzoassociates',
#  'alnylampharmaceuticals',
#  'coghlincompaniesinc',
#  'caseassociates',
#  'bostonpubliclibrary',
#  'fisherbusco',
#  'fulfillmentamerica',
#  'barrowsinsurance',
#  'familyserviceofgreaterboston',
#  'cityofbostoncu',
#  'sbventures',
#  'lincolnlaboratories',
#  'merrimackvalleyinsurance',
#  'parsonsbrinckerhoff',
#  'internationalinstituteofnewengland',
#  'poweroptions',
#  'beaconsservices',
#  'delanyassociates',
#  'dartmouthpublicschools',
#  'massmedicalassociates',
#  'vargasvargasinsurance',
#  'northeasthomeandenergy',
#  'sunovionpharmaceuticals',
#  'bostonuniversityschooloflaw',
#  'tfassociates',
#  'nerconstruction',
#  'richeywoodworking',
#  'vitaorgsolutions',
#  'fhperrybuilders',
#  'cloudkidstudios',
#  'frequencytherapeutics',
#  'hvac',
#  'morseinsagencyinc',
#  'rubywine',
#  'quirkautodealersinc',
#  'entrepreneurshipforall',
#  'columbiatech',
#  'converse',
#  'ashmontgrille',
#  'lawoffficeofmichaeldash',
#  'tesaroinc',
#  'syndaxpharmaceuticals',
#  'tarlowbreedhartrogerspc',
#  'everettfiredept',
#  'ecammnetwork',
#  'zfoundation',
#  'maldenpublicschools',
#  'jackconwaycompanyinc',
#  'wgbh',
#  'acronis',
#  'danversportyachtclub',
#  'sorellebakerycafe',
#  'sgp',
#  'westwoodpediatrics',
#  'southshoreelderservicesinc',
#  'deccoinc',
#  'rainbowballoonsinc',
#  'cdservices',
#  'corribrestaurant',
#  'tec',
#  'dartmouthbuildingsupply',
#  'corryassociatesllc',
#  'lowellregionaltransitauth',
#  'diversifiedfunding',
#  'cabotwealthmanangementinc',
#  'accunetsolutions',
#  'associationofbehaviorialhealth',
#  'enernoc',
#  'commonwealthofmass',
#  'meyersbrotheskalicka',
#  'sederchandler',
#  'keystonepartners',
#  'bmzdevelopmentllc',
#  'cambridgeassociatesllc',
#  'millstores',
#  'johnstait',
#  'trinityfinancial',
#  'panoramaeducation',
#  'beaconstrategiesgroup',
#  'macenterforhealthinformationandanalysis',
#  'massservice',
#  'nextworthsolutions',
#  'commonwealthcorporation',
#  'polarbeverages',
#  'directfinancecorp',
#  'morphotrustusa',
#  'delsaenterprises',
#  'allaccessphysicaltherapy',
#  'mtauburnhospital',
#  'umassmedicalschool',
#  'novus',
#  'linchrishotelcorporation',
#  'newenglandpetimaging',
#  'hayespump',
#  'davidking',
#  'sierrayanezlawllc',
#  'rklesolutionsllc',
#  'cambridgeassociates',
#  'bostonlandmarksorchestra',
#  'kesslermcguinnessassociatesllc',
#  'carrollcenterfortheblind',
#  'thecottingschool',
#  'bealsassociates',
#  'bristolcountychamberofcommerce',
#  'cityrealtygroup',
#  'williamsbuildingcompany',
#  'marraffaandassociates',
#  'resourceconnection',
#  'bostonhealthcareforthehomeless',
#  'donaghuebarrettsingal',
#  'gehealthcare',
#  'templebethavodah',
#  'townofsandwich',
#  'rancoenterprisesinc',
#  'muellerservices',
#  'winokurserkeyrosenbergpc',
#  'jinteractive',
#  'masssocietyforthepreventionofcrueltytochildren',
#  'brianhickeyassoc',
#  'greaterashmontmainstreet',
#  'hallassociates',
#  'leadingedgerealestate',
#  'leffoundation',
#  'georgetownbank',
#  'firstelectricmotorservice',
#  'covingtonassociates',
#  'mitpeerengage',
#  'richardsoninsurance',
#  'wgbheducationalfoundation',
#  'perkinsanctil',
#  'fitchburgstateuniversity',
#  'hyannismarina',
#  'realestateassociates',
#  'mcbr',
#  'meehanboyleblackandbogdanowpc',
#  'shadisrestaurant',
#  'clinicalsupportoptions',
#  'biobridges',
#  'crawfordcommunications',
#  'dicernapharmaceuticals',
#  'gallantinsuranceagency',
#  'sedarchandler',
#  'dunkinbrandsinc',
#  'churchhillconstruction',
#  'breurco',
#  'americanmeteorologicalsociety',
#  'mentor',
#  'oldetownerealestate',
#  'wingatehealthcare',
#  'boyleshaughnessylaw',
#  'collorallp',
#  'massaudobon',
#  'dayassociates',
#  'massachusettstrialcourt',
#  'thecopleygroup',
#  'bostonluxuryproperties',
#  'bostonpic',
#  'birchtreecapital',
#  'associatedindustriesofmassachusetts',
#  'adasolutionsinc',
#  'corwincorwinllp',
#  'cetrullollp',
#  'sarochiropractics',
#  'collegebounddorchester',
#  'morphotrust',
#  'southbaycommunityservices',
#  'debrasnaturalgourmet',
#  'communitycatalyst',
#  'valleyrealestate',
#  'townofraynham',
#  'cohenpartners',
#  'amex',
#  'politicalresearchassociates',
#  'primaceainc',
#  'massachusettslegalassistancecorp',
#  'commonwealthpsychologyassociates',
#  'digitas',
#  'cdmsmith',
#  'currentinstructionllc',
#  'fenwaycommunityhealthcenter',
#  'thedaviscompanies',
#  'powerproducts',
#  'tangierinorestaurant',
#  'centralmasshousingalliance',
#  'interactioninstituteforsocialchange',
#  'corrigancommunications',
#  'nuacinvestmentmanagement',
#  'manninggrossmassenburgllp',
#  'thesuffolkgroup',
#  'privateindustrycouncil',
#  'oneillproperties',
#  'publicconsultinggroupinc',
#  'townofwatertown',
#  'analogiccorporation',
#  'americancapitalenergy',
#  'atlasinvestmentgroup',
#  'stonehillcollege',
#  'edwardmkennedyinstitutefortheussenate',
#  'bluemetalarchitects',
#  'salemstateuniversity',
#  'alvianiassociates',
#  'learningprepschool',
#  'erabostonrealestategroup',
#  'excellacademycharterschool',
#  'thecommunitybuildersinc',
#  'terranoveassociates',
#  'gjwconstruction',
#  'loomissaylescompanyllc',
#  'frpublicschools',
#  'jvs',
#  'perkinelmer',
#  'jkarammanagement',
#  'richardwreidelectricalco',
#  'whistlersinn',
#  'applustechnologies',
#  'thehudsongroup',
#  'mainstreet',
#  'sherinlodgenllp',
#  'anthonyngiamberardino',
#  'bostonianconstructionservicesllc',
#  'nefwc',
#  'maniongaynormaningllp',
#  'syntaxpharmaceuticalsinc',
#  'thecommonwealthofmassachusetts',
#  'ryandevelopement',
#  'foderaconstructionco',
#  'stmicroelectronics',
#  'alfalfafarmwinery',
#  'hemenwaybarnes',
#  'columbiaconstructionco',
#  'youthphilanthropyconnect',
#  'longfellowrealestatepartnersllc',
#  'cignacorporation',
#  'paoliniassociates',
#  'mathasvineyardhospital',
#  'starwood',
#  'lpcontracting',
#  'silentspringinstitute',
#  'conwayinsuranceagency',
#  'wherbertgoodickinc',
#  'newenglandclaimsassociation',
#  'americanexpress',
#  'capitolgroup',
#  'princetonreview',
#  'equalexchange',
#  'commonwealthrealestate',
#  'themalloygroupinc',
#  'abcdisposal',
#  'amicainsurance',
#  'lakevillecountryclub',
#  'dcconsultingservices',
#  'suburbanlawnsprinkler',
#  'conwaycahillbrodeurfuneralhome',
#  'buyersbrokersllc',
#  'harmonyhealthcareinternational',
#  'mortonhospital',
#  'peterpanbuslines',
#  'millenniumpartners',
#  'fieldscornerbusinessbob',
#  'morseinsuranceagency',
#  'rosemonttrustllc',
#  'mansfieldbeautyschools',
#  'emersonhospital',
#  'murphyassociates',
#  'stephaniesonnewbury',
#  'kaneconstruction',
#  'amherstcinema',
#  'mayburymaterialhandling',
#  'partnersinhealth',
#  'piersparksailingcenter',
#  'davismalmdagostine',
#  'townofplymouth',
#  'thegandaracenter',
#  'waldenbehavioralcare',
#  'middlesexsheriff',
#  'massrehabcomission',
#  'fallriverpawnbroker',
#  'cantinaconsultinginc',
#  'princetonproperties',
#  'realestateco',
#  'hillcresteducationcenter',
#  'bcac',
#  'thesacrocompanies',
#  'beaconhillstaffing',
#  'gordoncollegge',
#  'retailersassocofmass',
#  'maassociationofschoolcommittees',
#  'riversidecommunitycare',
#  'mpaa',
#  'sallyfitchllp',
#  'lrcassociates',
#  'massachusettswomenspoliticalcaucus',
#  'barringtonstageco',
#  'childrenshospital',
#  'townofbarnstable',
#  'samaritans',
#  'pac',
#  'ferriternewardscobborodophelepc',
#  'mitlincolnlaboratories',
#  'charlesbankapartments',
#  'homeforlittlewanderers',
#  'amermeteorologicalsociety',
#  'morseinsurance',
#  'citizenshousingandplanningassociation',
#  'raskybaerleinstrategiccommunicationsinc',
#  'laheyhospitalandmedicalcenter',
#  'mdbeautysalon',
#  'meditech',
#  'healthresourcesinacton',
#  'cityofboston',
#  'mtec',
#  'lbcboston',
#  'utec',
#  'progresssoftware',
#  'aftmassachusetts',
#  'philjohnstonassociates',
#  'cityofquincyma',
#  'solomonmccown',
#  'patriotenergygroup',
#  'cra',
#  'thelongfellowclubs',
#  'primelandscaping',
#  'sentenialsystems',
#  'cityofnorthamptonma',
#  'crystalengineering',
#  'oconnordrewpc',
#  'zumix',
#  'norfolkcounty',
#  'fullcircletechnologies',
#  'heatherhillcountryclub',
#  'newenglandicecreamcorp',
#  'wcrib',
#  'newenglandcleanenergy',
#  'capecodfivecentssavingsbank',
#  'healthnewengland',
#  'bostonspinegroup',
#  'bostonfinancialinvestmentmanagement',
#  'townofnorthattleborough',
#  'verccarrental',
#  'commonwealthofmassa',
#  'caldwellbanker',
#  'lennoxinternational',
#  'northeastcenterforyouthandfamilies',
#  'homecityhousing',
#  'doctorfranklinperkinsschool',
#  'perlerarealestateinc',
#  'shawmutdesignconstruction',
#  'cplanhealthresourcesinaction',
#  'cityrealty',
#  'stewardhealthcare',
#  'bigjimsautobody',
#  'doulasokunassociates',
#  'burkedistributingcorporation',
#  'mendesmedicalassociates',
#  'energymanagement',
#  'zerovfx',
#  'jrsweeneyinsurance',
#  'fernwoodadvisorsinc',
#  'attnewengland',
#  'clarkeschool',
#  'bennettbelfort',
#  'humanscale',
#  'aawillmaterialscorp',
#  'townofabington',
#  'fsg',
#  'lambertsrainbowfruit',
#  'moneris',
#  'pinehills',
#  'optilineenterprisesllc',
#  'citizensforcitizensinc',
#  'northernconstructionllc',
#  'costellodismantlingco',
#  'sociallawlibrary',
#  'horsleywittengroup',
#  'patriotcontractingservicesllc',
#  'efg',
#  'qualitybeverageslp',
#  'envisionbank',
#  'allcomcreditunion',
#  'massachusettsinstituteoftechnology',
#  'plymouthchamberofcommerce',
#  'rcapitolinc',
#  'goldsteinlee',
#  'thecommunitybuilders',
#  'mbcr',
#  'acellaconstructioncorporation',
#  'greeneliteservices',
#  'unionofconcernedscientists',
#  'rehab',
#  'cotuitliquors',
#  'amconstruction',
#  'lathamcentersinc',
#  'dalygroup',
#  'linquestcorporation',
#  'phoenixinc',
#  'squareone',
#  'memberspluscreditunion',
#  'educationdevelomentcenteredc',
#  'osullivanassociates',
#  'tuftsuniversity',
#  'douglasfuneralhome',
#  'holyokegasandelectric',
#  'franciscanhospitalforchildren',
#  'brooklinepublicschools',
#  'acluofmassachusetts',
#  'jacobsvelellakerr',
#  'coutomanagementgroup',
#  'mit',
#  'bostoniangroup',
#  'raskypartnersinc',
#  'luceyinsuranceagencyinc',
#  'russiancommunityass',
#  'staddspecialist',
#  'lagonetautobodyandframe',
#  'everettpublicschools',
#  'bostonchildrenshospital',
#  'commonwealthma',
#  'thecommunitygroup',
#  'bealsthomasinc',
#  'contractor',
#  'bostonschoolsfunds',
#  'townofavon',
#  'kennedydonovancenter',
#  'lexingtonpublicschools',
#  'homestartinc',
#  'serlinehaleyllp',
#  'teamstersunionlocal',
#  'firstrealtymanagement',
#  'saltonstallco',
#  'northcentralworkforceinvestmentboard',
#  'quirkautodealers',
#  'rosalespartners',
#  'stjeanscreditunion',
#  'cryogenicinstituteofnewenglandinc',
#  'independentagent',
#  'marrrealestate',
#  'phillipsmanornursinghome',
#  'cooleymanionjones',
#  'phan',
#  'byrneandersonllp',
#  'simmonscollege',
#  'sunpower',
#  'commonwealthcare',
#  'dinosaurcapitalpartners',
#  'thevallegroup',
#  'globeliquors',
#  'neitzrealestate',
#  'kushgroove',
#  'marshfieldpublicschools',
#  'greaterspringfieldconventionandvisitorsbureauinc',
#  'capstickassociates',
#  'philipshealthcare',
#  'athenahealthcare',
#  'atruishealth',
#  'northbridgepartners',
#  'bristolcountydistrictattorney',
#  'sharonassociates',
#  'dowlinghouy',
#  'beckercollege',
#  'burkeelectricinc',
#  'soperlandscaping',
#  'massachusettsattorneygeneralsoffice',
#  'mariancourtcollege',
#  'windhamcapital',
#  'baesystems',
#  'lawofficesofcarmendurso',
#  'dataguidecable',
#  'cspace',
#  'thecolvestgroupllc',
#  'commofmasshouseofrepresentatives',
#  'giacomosrestaurant',
#  'hubtechnicalservicesllc',
#  'massachusettsbankersassociation',
#  'southcovecommunityhealthcenter',
#  'financeboston',
#  'harmoniclabsolutions',
#  'thevanngroup',
#  'rwholmesrealty',
#  'regencytransportationinc',
#  'autismsprinter',
#  'cornerstonerealestate',
#  'edtech',
#  'harpoonbrewery',
#  'intexsolutions',
#  'chesnuthillrealty',
#  'orsiniconsulting',
#  'thesylviagroup',
#  'falitebrothers',
#  'combieshanson',
#  'resnicbeauregardwaitedriscoll',
#  'empowerher',
#  'vendettimotors',
#  'flacccooperative',
#  'gregoryandassociates',
#  'jobsforthefuture',
#  'burrbrothersboatsinc',
#  'eaeducation',
#  'norfolkhardware',
#  'lawrencememorialhospital',
#  'fidelityinvestment',
#  'sentryford',
#  'virgilioconstruction',
#  'union',
#  'thehotelnorthampton',
#  'jrigroupllc',
#  'azinvestmentsllc',
#  'johnmcglynn',
#  'santanasrestaurant',
#  'uawlocal',
#  'africancommunityeducation',
#  'pjaadvertising',
#  'earthsource',
#  'rubertoisraelweinerpc',
#  'cruzcompanies',
#  'chmventures',
#  'bscgroup',
#  'landstrategies',
#  'mannorchards',
#  'bostonafterschoolandbeyond',
#  'copydirect',
#  'achivarestaurant',
#  'jrsproperties',
#  'saintsmemorialmedicalcenter',
#  'theedinburgcenter',
#  'cityonahillcharterschool',
#  'considineandfureyllp',
#  'sauconyinc',
#  'westendhouse',
#  'biogen',
#  'seniorassociate',
#  'longpondphysicaltherapy',
#  'communityadvocate',
#  'theassociationforcommunityliving',
#  'rmrealty',
#  'crystalfinancialllc',
#  'osramsylvaniainc',
#  'provencherinsurance',
#  'baystatephysicaltherapy',
#  'costelloinsurance',
#  'spiritofspringfieldinc',
#  'burnhamrosengroup',
#  'burkhartpizzanelly',
#  'quinnandmorrispc',
#  'dermodycleaners',
#  'harveysons',
#  'stewardhealthcaresystem',
#  'cchealthcare',
#  'haleyassociates',
#  'cityyear',
#  'worcester',
#  'buchananassociates',
#  'montachusettopportunitycouncil',
#  'mentalhealthassociationofgreaterlowell',
#  'pertistragegies',
#  'dohertyciechanowskidugancannon',
#  'aidsactioncommittee',
#  'colantonioinc',
#  'nicholaeffarchitecture',
#  'stonehamford',
#  'suffolkcountysheriffs',
#  'africancommunityeducationprogram',
#  'bigsisterassociationofgreaterboston',
#  'magellanjets',
#  'bridgewaterstateuniveristy',
#  'quirkautosales',
#  'brooklineperiodontal',
#  'curriculumassociates',
#  'miltonacademy',
#  'commonwealthcapitalcorp',
#  'somervillepublicschools',
#  'massachusettsassociationformentalhealth',
#  'remaxexecutiverealty',
#  'selfstonoverfarm',
#  'newenglandcenterforarttechnology',
#  'gmcstrategies',
#  'vinfen',
#  'enelgreenpowernorthamerica',
#  'amesburypsychologicalcenterinc',
#  'allianceofmassachusettsymcas',
#  'nigropettepitlucas',
#  'axiainsuranceagency',
#  'welchforbes',
#  'southshorementalhealth',
#  'jmarshallassociates',
#  'salarycom',
#  'kileycosgroveeisenbergkiley',
#  'pillpack',
#  'hughco',
#  'wesconinc',
#  'escofnewengland',
#  'springfieldtechcommunitycollege',
#  'kltassociatesinc',
#  'ferrierscobboandrodophelepc',
#  'gannonconstruction',
#  'providentbank',
#  'draperlaboratory',
#  'commonweathofmassachusetts',
#  'lombardos',
#  'theforsythinstitute',
#  'newenglandinstituteofart',
#  'middleborofamilydental',
#  'cvscorporation',
#  'easthorizoninvestments',
#  'wordsmithpress',
#  'bkwpartners',
#  'mohrmanassociates',
#  'hammondresidentialrealty',
#  'pentucketmedicalassociates',
#  'horizonbeverageco',
#  'cosgroveeisenberkiley',
#  'eastcambridgesavingsbank',
#  'rfwhiteassociates',
#  'longfellowdesignbuild',
#  'vanderweilengineers',
#  'beaconhotel',
#  'mjrconsulting',
#  'medpayinc',
#  'lubinmeyer',
#  'quincyasianresourcesinc',
#  'rsasecurityllc',
#  'commonwealthradiologyassociates',
#  'dempseyinsuranceagency',
#  'skyrestaurant',
#  'financialrecoverytechnologiesp',
#  'williamryanassociates',
#  'northruprealtors',
#  'balbonicommunicationsgroupllc',
#  'headsupirrigation',
#  'chateaurestaurant',
#  'mirracompany',
#  'theamfund',
#  'jarabekcharitablefoundation',
#  'sallyfitch',
#  'theactiongroup',
#  'mcphailassociatesinc',
#  'healthcarewithoutwalls',
#  'brookhavenatlexington',
#  'massachusettslodgingassociation',
#  'perfusionsupplyservicesinc',
#  'villaroseresturant',
#  'castechnologiesinc',
#  'massachusettsparentsunited',
#  'publicrelations',
#  'nhp',
#  'lopesfuneralhome',
#  'massachusettshealthhospitalassociation',
#  'wequassettinn',
#  'addisongroup',
#  'landmarkmanagementsolutions',
#  'couselbutkusjessonllp',
#  'friedmansuvallesalomoncpapc',
#  'bostoncenterless',
#  'murphydonahuepartners',
#  'whitmanhomes',
#  'williamcoyneassociates',
#  'mountholyokecollege',
#  'communityhealthlink',
#  'integratedpartners',
#  'tcamllc',
#  'mcompany',
#  'mswalker',
#  'mswalkerco',
#  'mirakproperties',
#  'segalryanbrennanpc',
#  'segalryanbrennan',
#  'charlesconstruction',
#  'lowellcommunityhealthctr',
#  'newenglandpowergenerationassociates',
#  'philrichardinsurance',
#  'crystalspringsinc',
#  'landmarkrealty',
#  'cardinalcushingcenters',
#  'commodorebuilders',
#  'mulkerinrealty',
#  'radiushealthcare',
#  'readingcooperativebank',
#  'wellscollege',
#  'lawofficesofpetertclarkpc',
#  'bostonfire',
#  'mahighwaydept',
#  'gagliarducciconstruction',
#  'heliescompany',
#  'keeganwirlinllp',
#  'gavinfoundation',
#  'kenneysames',
#  'acraneconstructioncompany',
#  'maassocofhealthplans',
#  'btgenvironmental',
#  'massgeneralhospital',
#  'nuciforolawgroupllc',
#  'caronassociates',
#  'veristat',
#  'theestevesgroup',
#  'teagnoconstructioninc',
#  'peabodyarnold',
#  'tooleinsurance',
#  'donovanhatemllp',
#  'harvardlawschool',
#  'sunsteinkannmurphytimbersllp',
#  'massafterschoolpartnership',
#  'easternbank',
#  'clinicalsupportoption',
#  'gilbertandrenton',
#  'darrylescornerbarkitchen',
#  'miniluxe',
#  'thecollaborativecompanies',
#  'csagraphics',
#  'tarvisrealtyllc',
#  'renaissanceco',
#  'gateshealthcare',
#  'massdevelopment',
#  'laheyclinicck',
#  'traggorthcompanies',
#  'signetelectronics',
#  'kimballfarms',
#  'lrassociates',
#  'brocktonhousingauthority',
#  'massachusettsattorneygeneral',
#  'chapdelainelawoffice',
#  'firstrealtymanagementco',
#  'magellandiagnostics',
#  'peabodyproperties',
#  'conroytalentassociates',
#  'retailmanagementanddevelopment',
#  'penobscotinvestmentmanagement',
#  'accutronicsinc',
#  'mci',
#  'fairfieldinn',
#  'harvardbusinessschool',
#  'concordfoods',
#  'songconsulting',
#  'lajoieinvestigations',
#  'ebbetsfieldcapitalmanagement',
#  'bostonmutual',
#  'cardinalcushingcentersinc',
#  'brighamandwomensfaulknerhospitalhospital',
#  'nouriaenergycorporation',
#  'shirepharmaceuticals',
#  'turboconsulting',
#  'ssecuritycorporation',
#  'quinnmorrispc',
#  'hooverrealtytrust',
#  'simondssaw',
#  'bcnc',
#  'merrimackvalleydistributing',
#  'autopartinternational',
#  'colonyfoods',
#  'waterfrontpropertiesllc',
#  'womanssheltercompaeras',
#  'rizemassachusetts',
#  'witmanpropertiesinc',
#  'concurtechnologies',
#  'folanwaterproofingcoinc',
#  'whippsinc',
#  'lawofficeskevinpatrickseaver',
#  'ymcagreaterboston',
#  'brodyhardoonperkinskesten',
#  'cityofattleboro',
#  'tecinc',
#  'pcom',
#  'isaacsonmiller',
#  'woodsholegolfclub',
#  'worceterpolytechnicinstitute',
#  'sylviagroup',
#  'educationdevelopmentcenter',
#  'berkshirehealthcaresystems',
#  'ris',
#  'formlabs',
#  'bostoncollegecenterforcorporatecitizenship',
#  'safewaytransportation',
#  'cityofbostoncreditunion',
#  'watertownpublicschools',
#  'keeganwerlinllp',
#  'mah',
#  'rossinsuranceagencyinc',
#  'serlinhaleyassociates',
#  'chestnuthillrealty',
#  'newenglandlawboston',
#  'girardfinancialgroup',
#  'caronconsulting',
#  'blueoxrestaurant',
#  'jmpaintconstruction',
#  'multiculturalhomecare',
#  'holdingsteenrealestate',
#  'srweinerassociatesinc',
#  'igemfoundation',
#  'hollandconstruction',
#  'printsynergysolutions',
#  'lawofficesofbrianmoran',
#  'raskypartners',
#  'jaycashmaninc',
#  'erconinc',
#  'houghtonmifflinharcout',
#  'familychiropractic',
#  'lawofficeofmichaelzaim',
#  'goodwinprocter',
#  'brandeisuniversityinternationalbusinessschool',
#  'marguliesperruzziarchitects',
#  'bostonrealtyadvisors',
#  'kellercompany',
#  'bostonpublichealthcommission',
#  'ferriterandferriterllc',
#  'oldneighborhoodfoods',
#  'policeofficer',
#  'recoveringchanpionsinc',
#  'nashobaschooldistrict',
#  'bbconstructionremodeling',
#  'showabostoninstitute',
#  'baystaehealth',
#  'priorityparking',
#  'avbconstruction',
#  'greencambridge',
#  'eastbostonsocialcenters',
#  'riceheardbigelowinc',
#  'edwardstreetdaycarecenter',
#  'newyorkinstituteoftechnology',
#  'conte',
#  'ambri',
#  'kelleherandsadowsky',
#  'architect',
#  'bowdoingenevamainstreets',
#  'mwraadvisoryboard',
#  'atlantischarterschool',
#  'northshorepatentspc',
#  'morrislawoffice',
#  'newenglandcenter',
#  'massachusettscollegeofartanddesign',
#  'nfib',
#  'usvisothebysinternationalrealty',
#  'atlanticcharterschool',
#  'williameryanassociates',
#  'prosperitycandle',
#  'chineseprogressiveassociation',
#  'solomonmccowan',
#  'melloconstruction',
#  'ferriterscoboorodophelepc',
#  'landtechconsultants',
#  'banecaremanagement',
#  'rbadvisory',
#  'coughlinbetkellp',
#  'highlandliquors',
#  'northeastutilities',
#  'wilsonfarm',
#  'mpha',
#  'dailytable',
#  'metropolitanbostonhousingpartnershipinc',
#  'greenmeadowfarms',
#  'klkenterprises',
#  'mgnassociates',
#  'foleyhoagllp',
#  'kendallhotel',
#  'baublesinc',
#  'commonweatlhofmassachusetts',
#  'sanofigenzyme',
#  'theesplanadeassociation',
#  'massachusettsbiotechnologycouncil',
#  'middlesexsavingsbank',
#  'rightturn',
#  'springbankpharmaceuticals',
#  'tarlowbreedhartrodgerspc',
#  'thorntonlawfirmllc',
#  'galanteinsurance',
#  'cpacconstruction',
#  'eastcoastseafood',
#  'thelenoxhotel',
#  'macgraycorporation',
#  'kingbishop',
#  'gfindustries',
#  'oneilconsulting',
#  'elpelantaqueria',
#  'metropolitanuniformlinen',
#  'admanagementcorp',
#  'eastonpublicschools',
#  'fsquaredinvestmentsinc',
#  'michelassociates',
#  'thearchitecturalteam',
#  'eyehealthassociates',
#  'leahyhealth',
#  'winthrop',
#  'prellwitzchilinskiassociates',
#  'thecateredaffair',
#  'mitrecorporation',
#  'baesisinc',
#  'antoniosrestaurant',
#  'zamirchoraleofboston',
#  'oceanspraycranberriesinc',
#  'peopleinc',
#  'massachusettsstatepolice',
#  'plannedparenthoodofmassachusetts',
#  'matechcorp',
#  'holyokecreditunion',
#  'chamberofcommerce',
#  'falloncompany',
#  ...}

# %%
len(match_set)
# Out:
# 5337

# %%
match_ind = {}
for com in match_set:
    industry = df_companies[df_companies['Company_clean'] == com]['Industry'].values
    if len(industry) == 0:
        continue
    match_ind[com] = industry[0]

# %%
len(match_ind)
# Out:
# 2088

# %%
match_ind
# Out:
# {'obrienassociates': 'financial services',
#  'westfieldbank': 'banking',
#  'bristolcountysavingsbank': 'banking',
#  'bostonportfolioadvisers': 'investment management',
#  'realestate': 'real estate',
#  'bluehillcemetery': 'individual & family services',
#  'confluentsurgical': 'medical devices',
#  'greaterhaverhillchamberofcommerce': 'civic & social organization',
#  'wayfair': 'internet',
#  'independentcontractor': 'non-profit organization management',
#  'harvarduniversity': 'higher education',
#  'careerpoint': 'staffing and recruiting',
#  'borislowinsurance': 'insurance',
#  'agency': 'marketing and advertising',
#  'berkshirehealthsystems': 'hospital & health care',
#  'vesonnautical': 'computer software',
#  'dearbornacademy': 'primary/secondary education',
#  'brocktonneighborhoodhealthcenter': 'medical practice',
#  'uaspire': 'higher education',
#  'rismaninsurance': 'insurance',
#  'projectrightinc': 'individual & family services',
#  'bostonseniorhomecare': 'hospital & health care',
#  'publicconsultinggroup': 'management consulting',
#  'maxwellhealth': 'information technology and services',
#  'pittsfieldpublicschools': 'education management',
#  'stmaryscreditunion': 'banking',
#  'massachusetts': 'public policy',
#  'marcottefordsalesinc': 'automotive',
#  'shorelighteducation': 'higher education',
#  'omninavitas': 'renewables & environment',
#  'townofframingham': 'government administration',
#  'thehollandcompanies': 'construction',
#  'newenglandschoolofacupuncture': 'higher education',
#  'williamjamescollege': 'higher education',
#  'centerforhumandevelopmentinc': 'entertainment',
#  'msamortgage': 'real estate',
#  'costantinorichardsrizzollp': 'accounting',
#  'binkeezforcomfort': 'philanthropy',
#  'perkinsschoolfortheblind': 'primary/secondary education',
#  'leaderbank': 'banking',
#  'raytheon': 'defense & space',
#  'aptushealth': 'marketing and advertising',
#  'armstrongadvisorygroup': 'financial services',
#  'alnylampharmaceuticals': 'biotechnology',
#  'coghlincompaniesinc': 'electrical/electronic manufacturing',
#  'bostonpubliclibrary': 'libraries',
#  'fulfillmentamerica': 'warehousing',
#  'familyserviceofgreaterboston': 'non-profit organization management',
#  'internationalinstituteofnewengland': 'non-profit organization management',
#  'vargasvargasinsurance': 'insurance',
#  'bostonuniversityschooloflaw': 'higher education',
#  'nerconstruction': 'construction',
#  'cloudkidstudios': 'media production',
#  'frequencytherapeutics': 'biotechnology',
#  'hvac': 'telecommunications',
#  'columbiatech': 'electrical/electronic manufacturing',
#  'converse': 'apparel & fashion',
#  'tesaroinc': 'pharmaceuticals',
#  'syndaxpharmaceuticals': 'biotechnology',
#  'everettfiredept': 'public safety',
#  'maldenpublicschools': 'education management',
#  'wgbh': 'broadcast media',
#  'acronis': 'computer software',
#  'danversportyachtclub': 'international affairs',
#  'sorellebakerycafe': 'construction',
#  'dartmouthbuildingsupply': 'building materials',
#  'lowellregionaltransitauth': 'transportation/trucking/railroad',
#  'accunetsolutions': 'computer & network security',
#  'enernoc': 'information technology and services',
#  'commonwealthofmass': 'hospital & health care',
#  'sederchandler': 'law practice',
#  'keystonepartners': 'human resources',
#  'cambridgeassociatesllc': 'financial services',
#  'millstores': 'retail',
#  'panoramaeducation': 'education management',
#  'beaconstrategiesgroup': 'government relations',
#  'commonwealthcorporation': 'government administration',
#  'polarbeverages': 'food & beverages',
#  'morphotrustusa': 'security and investigations',
#  'allaccessphysicaltherapy': 'health, wellness and fitness',
#  'mtauburnhospital': 'hospital & health care',
#  'umassmedicalschool': 'research',
#  'linchrishotelcorporation': 'hospitality',
#  'newenglandpetimaging': 'hospital & health care',
#  'sierrayanezlawllc': 'law practice',
#  'cambridgeassociates': 'financial services',
#  'bostonlandmarksorchestra': 'music',
#  'kesslermcguinnessassociatesllc': 'management consulting',
#  'carrollcenterfortheblind': 'non-profit organization management',
#  'cityrealtygroup': 'real estate',
#  'templebethavodah': 'primary/secondary education',
#  'townofsandwich': 'government administration',
#  'rancoenterprisesinc': 'construction',
#  'winokurserkeyrosenbergpc': 'legal services',
#  'jinteractive': 'information technology and services',
#  'brianhickeyassoc': 'public relations and communications',
#  'greaterashmontmainstreet': 'civic & social organization',
#  'leadingedgerealestate': 'real estate',
#  'georgetownbank': 'banking',
#  'firstelectricmotorservice': 'industrial automation',
#  'covingtonassociates': 'investment banking',
#  'richardsoninsurance': 'insurance',
#  'fitchburgstateuniversity': 'higher education',
#  'biobridges': 'pharmaceuticals',
#  'americanmeteorologicalsociety': 'publishing',
#  'wingatehealthcare': 'hospital & health care',
#  'boyleshaughnessylaw': 'law practice',
#  'collorallp': 'law practice',
#  'dayassociates': 'semiconductors',
#  'massachusettstrialcourt': 'judiciary',
#  'thecopleygroup': 'real estate',
#  'associatedindustriesofmassachusetts': 'government relations',
#  'corwincorwinllp': 'law practice',
#  'collegebounddorchester': 'education management',
#  'debrasnaturalgourmet': 'food & beverages',
#  'communitycatalyst': 'non-profit organization management',
#  'townofraynham': 'government administration',
#  'politicalresearchassociates': 'non-profit organization management',
#  'primaceainc': 'hospital & health care',
#  'digitas': 'marketing and advertising',
#  'cdmsmith': 'civil engineering',
#  'thedaviscompanies': 'staffing and recruiting',
#  'centralmasshousingalliance': 'construction',
#  'interactioninstituteforsocialchange': 'non-profit organization management',
#  'manninggrossmassenburgllp': 'law practice',
#  'privateindustrycouncil': 'non-profit organization management',
#  'townofwatertown': 'government administration',
#  'americancapitalenergy': 'renewables & environment',
#  'stonehillcollege': 'higher education',
#  'bluemetalarchitects': 'computer software',
#  'salemstateuniversity': 'higher education',
#  'learningprepschool': 'primary/secondary education',
#  'erabostonrealestategroup': 'real estate',
#  'thecommunitybuildersinc': 'real estate',
#  'thehudsongroup': 'information technology and services',
#  'alfalfafarmwinery': 'information services',
#  'hemenwaybarnes': 'law practice',
#  'longfellowrealestatepartnersllc': 'real estate',
#  'silentspringinstitute': 'research',
#  'wherbertgoodickinc': 'construction',
#  'princetonreview': 'higher education',
#  'equalexchange': 'food & beverages',
#  'lakevillecountryclub': 'real estate',
#  'harmonyhealthcareinternational': 'hospital & health care',
#  'mortonhospital': 'hospital & health care',
#  'rosemonttrustllc': 'primary/secondary education',
#  'mansfieldbeautyschools': 'human resources',
#  'emersonhospital': 'hospital & health care',
#  'stephaniesonnewbury': 'hospitality',
#  'kaneconstruction': 'construction',
#  'amherstcinema': 'fine art',
#  'mayburymaterialhandling': 'facilities services',
#  'partnersinhealth': 'hospital & health care',
#  'piersparksailingcenter': 'recreational facilities and services',
#  'townofplymouth': 'government administration',
#  'waldenbehavioralcare': 'mental health care',
#  'princetonproperties': 'real estate',
#  'riversidecommunitycare': 'mental health care',
#  'sallyfitchllp': 'law practice',
#  'massachusettswomenspoliticalcaucus': 'political organization',
#  'townofbarnstable': 'government administration',
#  'pac': 'business supplies and equipment',
#  'meditech': 'information technology and services',
#  'cityofboston': 'government administration',
#  'utec': 'non-profit organization management',
#  'patriotenergygroup': 'utilities',
#  'cra': 'non-profit organization management',
#  'oconnordrewpc': 'accounting',
#  'zumix': 'music',
#  'heatherhillcountryclub': 'sports',
#  'newenglandcleanenergy': 'renewables & environment',
#  'healthnewengland': 'insurance',
#  'bostonfinancialinvestmentmanagement': 'financial services',
#  'townofnorthattleborough': 'civic & social organization',
#  'verccarrental': 'automotive',
#  'northeastcenterforyouthandfamilies': 'individual & family services',
#  'homecityhousing': 'real estate',
#  'doctorfranklinperkinsschool': 'individual & family services',
#  'stewardhealthcare': 'staffing and recruiting',
#  'bigjimsautobody': 'automotive',
#  'burkedistributingcorporation': 'food & beverages',
#  'zerovfx': 'motion pictures and film',
#  'fernwoodadvisorsinc': 'professional training & coaching',
#  'aawillmaterialscorp': 'business supplies and equipment',
#  'fsg': 'management consulting',
#  'lambertsrainbowfruit': 'construction',
#  'citizensforcitizensinc': 'individual & family services',
#  'sociallawlibrary': 'law practice',
#  'envisionbank': 'banking',
#  'allcomcreditunion': 'banking',
#  'thecommunitybuilders': 'marketing and advertising',
#  'unionofconcernedscientists': 'renewables & environment',
#  'cotuitliquors': 'retail',
#  'lathamcentersinc': 'facilities services',
#  'phoenixinc': 'machinery',
#  'squareone': 'individual & family services',
#  'memberspluscreditunion': 'banking',
#  'tuftsuniversity': 'higher education',
#  'franciscanhospitalforchildren': 'hospital & health care',
#  'bostonchildrenshospital': 'hospital & health care',
#  'thecommunitygroup': 'non-profit organization management',
#  'kennedydonovancenter': 'non-profit organization management',
#  'lexingtonpublicschools': 'education management',
#  'homestartinc': 'real estate',
#  'firstrealtymanagement': 'real estate',
#  'saltonstallco': 'financial services',
#  'quirkautodealers': 'automotive',
#  'rosalespartners': 'architecture & planning',
#  'stjeanscreditunion': 'banking',
#  'cryogenicinstituteofnewenglandinc': 'medical devices',
#  'byrneandersonllp': 'law practice',
#  'simmonscollege': 'higher education',
#  'dinosaurcapitalpartners': 'real estate',
#  'kushgroove': 'apparel & fashion',
#  'philipshealthcare': 'medical devices',
#  'northbridgepartners': 'real estate',
#  'sharonassociates': 'civil engineering',
#  'beckercollege': 'higher education',
#  'massachusettsattorneygeneralsoffice': 'legal services',
#  'mariancourtcollege': 'higher education',
#  'cspace': 'management consulting',
#  'massachusettsbankersassociation': 'banking',
#  'financeboston': 'commercial real estate',
#  'harmoniclabsolutions': 'biotechnology',
#  'regencytransportationinc': 'transportation/trucking/railroad',
#  'autismsprinter': 'non-profit organization management',
#  'harpoonbrewery': 'food & beverages',
#  'resnicbeauregardwaitedriscoll': 'law practice',
#  'empowerher': 'non-profit organization management',
#  'vendettimotors': 'transportation/trucking/railroad',
#  'jobsforthefuture': 'education management',
#  'sentryford': 'automotive',
#  'union': 'graphic design',
#  'uawlocal': 'human resources',
#  'africancommunityeducation': 'education management',
#  'rubertoisraelweinerpc': 'law practice',
#  'cruzcompanies': 'construction',
#  'bscgroup': 'civil engineering',
#  'copydirect': 'computer & network security',
#  'saintsmemorialmedicalcenter': 'hospital & health care',
#  'theedinburgcenter': 'individual & family services',
#  'sauconyinc': 'consumer goods',
#  'westendhouse': 'civic & social organization',
#  'biogen': 'biotechnology',
#  'longpondphysicaltherapy': 'health, wellness and fitness',
#  'communityadvocate': 'libraries',
#  'theassociationforcommunityliving': 'non-profit organization management',
#  'crystalfinancialllc': 'financial services',
#  'baystatephysicaltherapy': 'health, wellness and fitness',
#  'burnhamrosengroup': 'professional training & coaching',
#  'dermodycleaners': 'textiles',
#  'cityyear': 'non-profit organization management',
#  'aidsactioncommittee': 'non-profit organization management',
#  'colantonioinc': 'construction',
#  'stonehamford': 'automotive',
#  'bigsisterassociationofgreaterboston': 'non-profit organization management',
#  'magellanjets': 'airlines/aviation',
#  'curriculumassociates': 'publishing',
#  'miltonacademy': 'education management',
#  'somervillepublicschools': 'education management',
#  'massachusettsassociationformentalhealth': 'public policy',
#  'remaxexecutiverealty': 'real estate',
#  'vinfen': 'non-profit organization management',
#  'enelgreenpowernorthamerica': 'utilities',
#  'amesburypsychologicalcenterinc': 'mental health care',
#  'allianceofmassachusettsymcas': 'non-profit organization management',
#  'southshorementalhealth': 'mental health care',
#  'salarycom': 'computer software',
#  'pillpack': 'hospital & health care',
#  'wesconinc': 'civil engineering',
#  'escofnewengland': 'non-profit organization management',
#  'draperlaboratory': 'defense & space',
#  'lombardos': 'events services',
#  'theforsythinstitute': 'research',
#  'easthorizoninvestments': 'investment management',
#  'pentucketmedicalassociates': 'hospital & health care',
#  'eastcambridgesavingsbank': 'banking',
#  'longfellowdesignbuild': 'construction',
#  'vanderweilengineers': 'mechanical or industrial engineering',
#  'quincyasianresourcesinc': 'civic & social organization',
#  'commonwealthradiologyassociates': 'hospital & health care',
#  'chateaurestaurant': 'food & beverages',
#  'healthcarewithoutwalls': 'hospital & health care',
#  'brookhavenatlexington': 'hospital & health care',
#  'massachusettslodgingassociation': 'hospitality',
#  'perfusionsupplyservicesinc': 'hospital & health care',
#  'castechnologiesinc': 'machinery',
#  'massachusettsparentsunited': 'civic & social organization',
#  'publicrelations': 'public relations and communications',
#  'nhp': 'information technology and services',
#  'wequassettinn': 'arts and crafts',
#  'bostoncenterless': 'mining & metals',
#  'whitmanhomes': 'real estate',
#  'mountholyokecollege': 'higher education',
#  'tcamllc': 'investment management',
#  'segalryanbrennanpc': 'law practice',
#  'crystalspringsinc': 'non-profit organization management',
#  'commodorebuilders': 'construction',
#  'readingcooperativebank': 'banking',
#  'massgeneralhospital': 'higher education',
#  'nuciforolawgroupllc': 'law practice',
#  'veristat': 'pharmaceuticals',
#  'teagnoconstructioninc': 'construction',
#  'donovanhatemllp': 'law practice',
#  'harvardlawschool': 'higher education',
#  'sunsteinkannmurphytimbersllp': 'law practice',
#  'easternbank': 'banking',
#  'miniluxe': 'consumer services',
#  'thecollaborativecompanies': 'real estate',
#  'massdevelopment': 'government administration',
#  'peabodyproperties': 'real estate',
#  'harvardbusinessschool': 'higher education',
#  'concordfoods': 'food & beverages',
#  'lajoieinvestigations': 'legal services',
#  'ebbetsfieldcapitalmanagement': 'investment management',
#  'cardinalcushingcentersinc': 'non-profit organization management',
#  'nouriaenergycorporation': 'retail',
#  'ssecuritycorporation': 'computer software',
#  'quinnmorrispc': 'law practice',
#  'hooverrealtytrust': 'construction',
#  'simondssaw': 'industrial automation',
#  'merrimackvalleydistributing': 'food & beverages',
#  'autopartinternational': 'automotive',
#  'whippsinc': 'machinery',
#  'cityofattleboro': 'government administration',
#  'isaacsonmiller': 'staffing and recruiting',
#  'woodsholegolfclub': 'food & beverages',
#  'sylviagroup': 'insurance',
#  'educationdevelopmentcenter': 'research',
#  'formlabs': 'consumer electronics',
#  'bostoncollegecenterforcorporatecitizenship': 'research',
#  'cityofbostoncreditunion': 'financial services',
#  'watertownpublicschools': 'education management',
#  'keeganwerlinllp': 'law practice',
#  'chestnuthillrealty': 'real estate',
#  'newenglandlawboston': 'higher education',
#  'multiculturalhomecare': 'hospital & health care',
#  'holdingsteenrealestate': 'real estate',
#  'igemfoundation': 'higher education',
#  'printsynergysolutions': 'printing',
#  'raskypartners': 'public relations and communications',
#  'jaycashmaninc': 'civil engineering',
#  'marguliesperruzziarchitects': 'architecture & planning',
#  'bostonrealtyadvisors': 'real estate',
#  'bostonpublichealthcommission': 'government administration',
#  'oldneighborhoodfoods': 'food production',
#  'showabostoninstitute': 'education management',
#  'eastbostonsocialcenters': 'non-profit organization management',
#  'riceheardbigelowinc': 'financial services',
#  'ambri': 'oil & energy',
#  'bowdoingenevamainstreets': 'civic & social organization',
#  'atlantischarterschool': 'education management',
#  'northshorepatentspc': 'law practice',
#  'massachusettscollegeofartanddesign': 'higher education',
#  'prosperitycandle': 'retail',
#  'chineseprogressiveassociation': 'non-profit organization management',
#  'landtechconsultants': 'civil engineering',
#  'coughlinbetkellp': 'law practice',
#  'highlandliquors': 'consumer services',
#  'wilsonfarm': 'food & beverages',
#  'dailytable': 'supermarkets',
#  'klkenterprises': 'construction',
#  'foleyhoagllp': 'law practice',
#  'kendallhotel': 'hospitality',
#  'sanofigenzyme': 'biotechnology',
#  'theesplanadeassociation': 'environmental services',
#  'middlesexsavingsbank': 'banking',
#  'rightturn': 'mental health care',
#  'tarlowbreedhartrodgerspc': 'law practice',
#  'eastcoastseafood': 'wholesale',
#  'kingbishop': 'staffing and recruiting',
#  'thearchitecturalteam': 'architecture & planning',
#  'prellwitzchilinskiassociates': 'architecture & planning',
#  'thecateredaffair': 'food & beverages',
#  'baesisinc': 'computer software',
#  'antoniosrestaurant': 'electrical/electronic manufacturing',
#  'oceanspraycranberriesinc': 'food & beverages',
#  'massachusettsstatepolice': 'hospital & health care',
#  'holyokecreditunion': 'banking',
#  'servicenetinc': 'mental health care',
#  'townofnewbury': 'public safety',
#  'buckinghambrownenicholsschool': 'primary/secondary education',
#  'personalbestkarate': 'health, wellness and fitness',
#  'bosecorporation': 'consumer electronics',
#  'spanishamericancenter': 'civic & social organization',
#  'caregiverhomes': 'hospital & health care',
#  'fboston': 'events services',
#  'clearpathforveteransnewengland': 'military',
#  'whitefreemanwinterllp': 'law practice',
#  'harvardmedicalschool': 'higher education',
#  'tremontstrategiesgroup': 'government relations',
#  'vivwebsolutions': 'marketing and advertising',
#  'cummingsschool': 'education management',
#  'healthedge': 'computer software',
#  'healthcaresouth': 'hospital & health care',
#  'bresnahaninsuranceagency': 'insurance',
#  'milesfuneralhome': 'individual & family services',
#  'millcityenvironmental': 'environmental services',
#  'southendcommunityhealthcenter': 'hospital & health care',
#  'massachusettstechnologycollaborative': 'government administration',
#  'conductorproductions': 'media production',
#  'reachoutandread': 'non-profit organization management',
#  'eastbostonneighborhoodhealthcenter': 'hospital & health care',
#  'newbostonfund': 'real estate',
#  'cuseum': 'internet',
#  'demeollp': 'legal services',
#  'appellatetaxboard': 'government administration',
#  'westonsampson': 'civil engineering',
#  'awchestertoncompany': 'mechanical or industrial engineering',
#  'nixonpeabodyllp': 'law practice',
#  'newbedfordfestivaltheatre': 'entertainment',
#  'smolakfarms': 'hospital & health care',
#  'islandterracenursinghome': 'hospital & health care',
#  'hammondresidential': 'real estate',
#  'mauirestaurant': 'marketing and advertising',
#  'cycles': 'architecture & planning',
#  'emersoncollege': 'higher education',
#  'newenglandboardofhighereducation': 'higher education',
#  'aladcolinenservices': 'transportation/trucking/railroad',
#  'redgate': 'real estate',
#  'sistersofprovidencehealthsystem': 'hospital & health care',
#  'mcleanhospital': 'mental health care',
#  'donovanoconnorllp': 'law practice',
#  'newenglandfoundationforthearts': 'non-profit organization management',
#  'tudorriskservices': 'insurance',
#  'mccarterenglishllp': 'law practice',
#  'americanredcrossofmassachusetts': 'non-profit organization management',
#  'samaritansinc': 'mental health care',
#  'airworldwide': 'insurance',
#  'andoverschoolofmontessori': 'primary/secondary education',
#  'easternstatesexposition': 'events services',
#  'mggroup': 'real estate',
#  'advantageresourcing': 'staffing and recruiting',
#  'scholarathletes': 'non-profit organization management',
#  'lantelcommunicationsinc': 'telecommunications',
#  'milfordregionalmedicalcenter': 'hospital & health care',
#  'westernnewenglanduniversity': 'higher education',
#  'seabornnetworks': 'telecommunications',
#  'southernmasscreditunion': 'financial services',
#  'grossmanmarketinggroup': 'marketing and advertising',
#  'womenslunchplace': 'non-profit organization management',
#  'northendwaterfronthealth': 'hospital & health care',
#  'websterinsurance': 'insurance',
#  'massalliance': 'political organization',
#  'kaiserlawgroup': 'law practice',
#  'roadhouse': 'restaurants',
#  'kleinhornigllp': 'law practice',
#  'framinghamcooperativebank': 'banking',
#  'fouroakscountryclub': 'entertainment',
#  'sconsettrustinc': 'non-profit organization management',
#  'masscreative': 'civic & social organization',
#  'firstparishinbedford': 'religious institutions',
#  'kingstonpubliclibrary': 'libraries',
#  'gormanfinancialmanagement': 'financial services',
#  'mitre': 'information technology and services',
#  'unitedsiteservices': 'events services',
#  'madeptofmentalhealth': 'government administration',
#  'restaurant': 'public relations and communications',
#  'wellesleypublicschools': 'primary/secondary education',
#  'walker': 'primary/secondary education',
#  'directfederalcreditunion': 'banking',
#  'fallonambulanceservice': 'hospital & health care',
#  'hreskoassociatesinc': 'accounting',
#  'hamiltonwenhamregionalhighschool': 'education management',
#  'feeleydriscollpc': 'accounting',
#  'cooleydickinsonhospital': 'hospital & health care',
#  'nextsunenergy': 'renewables & environment',
#  'bluecrossblueshieldofmassachusetts': 'insurance',
#  'trinitymanagementllc': 'real estate',
#  'adamsclinical': 'pharmaceuticals',
#  'shieldshealthcaregroup': 'hospital & health care',
#  'dohertyciechanowskidugancannonpc': 'law practice',
#  'commonwealth': 'restaurants',
#  'holyokecommunitycollege': 'higher education',
#  'isabellastewartgardnermuseum': 'museums and institutions',
#  'assumptioncollege': 'higher education',
#  'rocklandmontessorischool': 'education management',
#  'pricewaterhousecooper': 'accounting',
#  'cargurus': 'internet',
#  'childrensfriendinc': 'non-profit organization management',
#  'harvardkennedyschool': 'public policy',
#  'normanrockwellmuseum': 'museums and institutions',
#  'capitolconsultinggroupllc': 'government relations',
#  'flagshipventures': 'venture capital & private equity',
#  'ivychildinternational': 'education management',
#  'nationalcommercialbrokers': 'retail',
#  'bostontextile': 'textiles',
#  'clintonsavingsbank': 'banking',
#  'mapfreinsurance': 'insurance',
#  'costellodismantling': 'construction',
#  'suffolkuniversitylawschool': 'higher education',
#  'peabodyessexmuseum': 'museums and institutions',
#  'psychiatrichomecareservices': 'hospital & health care',
#  'quincymutualgroup': 'insurance',
#  'harvardpilgrimhealthcare': 'health, wellness and fitness',
#  'nolansheehanpattenllp': 'real estate',
#  'roxburycommunitycollege': 'education management',
#  'unionoysterhouse': 'food & beverages',
#  'yarmouthresort': 'hospitality',
#  'cabotcabotforbes': 'real estate',
#  'newburyportfamilypractice': 'law practice',
#  'falmouthacademy': 'primary/secondary education',
#  'themathworks': 'computer software',
#  'moodystreetpictures': 'media production',
#  'citypointcapital': 'investment management',
#  'lynchassociatesinc': 'government relations',
#  'coldwellbanker': 'real estate',
#  'bostonuniversityschoolofpublichealth': 'higher education',
#  'bostoncommunitycapital': 'non-profit organization management',
#  'callahaninc': 'construction',
#  'museumofscience': 'museums and institutions',
#  'cambridgetrustcompany': 'banking',
#  'winthrophousingauthority': 'real estate',
#  'newtonpublicschools': 'education management',
#  'constantcontact': 'computer software',
#  'karondalimontellp': 'law practice',
#  'eatonapothecary': 'health, wellness and fitness',
#  'commonwealthofma': 'facilities services',
#  'breuerco': 'information technology and services',
#  'safetyinsurance': 'insurance',
#  'cityoftaunton': 'government administration',
#  'websterfive': 'financial services',
#  'pepperoniexpress': 'restaurants',
#  'guaettabensonllc': nan,
#  'virgiliopropertymanagement': 'real estate',
#  'performancebuildingcoinc': 'construction',
#  'bowditchdeweyllp': 'law practice',
#  'fallriverpublicschools': 'primary/secondary education',
#  'baypathuniversity': 'higher education',
#  'justiceatwork': 'legal services',
#  'theconcordconsortium': 'primary/secondary education',
#  'saviolighting': 'retail',
#  'phillipsinsuranceagency': 'insurance',
#  'etlconstruction': 'construction',
#  'avidiabank': 'banking',
#  'avaryrtginc': 'facilities services',
#  'calarepropertiesinc': 'investment management',
#  'foxborofederalsavings': 'financial services',
#  'nelliemaeeducationfoundation': 'philanthropy',
#  'stopshop': 'retail',
#  'elmscollege': 'higher education',
#  'thirdsectornewengland': 'non-profit organization management',
#  'bostonbaseball': 'consumer goods',
#  'talbots': 'retail',
#  'draftkingsinc': 'internet',
#  'copelandchevrolet': 'automotive',
#  'meredithmanagementcorp': 'public relations and communications',
#  'paramountpartnersllc': 'real estate',
#  'businessconsultinggroupllc': 'investment banking',
#  'continuum': 'design',
#  'winncompanies': 'real estate',
#  'lcandersoninc': 'construction',
#  'techbuilt': 'construction',
#  'capecodbroadcasting': 'broadcast media',
#  'nigropettepitlucasllp': 'law practice',
#  'townofhopkintonma': 'government administration',
#  'lexingtoneyeassociates': 'medical practice',
#  'youbiqllc': 'internet',
#  'wsdevelopment': 'commercial real estate',
#  'sheehanfamilycompanies': 'wine and spirits',
#  'jennifergoldmanconsulting': 'management consulting',
#  'perkinelmerinc': 'biotechnology',
#  'allianceenergy': 'oil & energy',
#  'tapestryhealth': 'hospital & health care',
#  'salemfivebank': 'banking',
#  'schoonercapital': 'venture capital & private equity',
#  'epms': 'computer software',
#  'worcestercenterforcrafts': 'arts and crafts',
#  'cityofcambridge': 'government administration',
#  'bostoninvestments': 'real estate',
#  'lowellfivebank': 'banking',
#  'emdseronoinc': 'biotechnology',
#  'rinetcompanyllc': 'financial services',
#  'remaxpartners': 'real estate',
#  'worcesterpublishingltd': 'graphic design',
#  'borcherstrustlawgrouppc': 'law practice',
#  'doveinc': 'health, wellness and fitness',
#  'trurovineyardsofcapecod': 'consumer goods',
#  'bostoncapitalventures': 'venture capital & private equity',
#  'newenglandbusinesspartners': 'management consulting',
#  'brownrudnickllp': 'law practice',
#  'solomonmccownco': 'public relations and communications',
#  'johnmcorcoranandcompany': 'real estate',
#  'massachusettsaflcio': 'public policy',
#  'sloweymcmanuscommunications': 'public relations and communications',
#  'avenuemanagement': 'commercial real estate',
#  'jmhcapital': 'investment management',
#  'ckstrategies': 'political organization',
#  'rfwalshco': 'construction',
#  'thorntonlawfirmllp': 'legal services',
#  'applewildschool': 'primary/secondary education',
#  'primacare': 'medical practice',
#  'maestranzibrothers': 'facilities services',
#  'jcalnanassociatesinc': 'construction',
#  'anthonyspier': 'restaurants',
#  'metrohousingboston': 'non-profit organization management',
#  'firstcitizensfederalcreditunion': 'banking',
#  'madisongroupinc': 'marketing and advertising',
#  'riverbendanimalhospital': 'veterinary',
#  'harvestpowerinc': 'renewables & environment',
#  'strategicbenefitadvisors': 'insurance',
#  'ironmountain': 'information technology and services',
#  'us': 'non-profit organization management',
#  'massmep': 'management consulting',
#  'umassdartmouth': 'higher education',
#  'plymouthpublicschools': 'education management',
#  'bestdoctors': 'health, wellness and fitness',
#  'compassmedical': 'medical practice',
#  'lebelcherinc': 'oil & energy',
#  'esdailebarrettesdaile': 'law practice',
#  'denterlein': 'public relations and communications',
#  'bmchealthnetplan': 'hospital & health care',
#  'brainshark': 'computer software',
#  'baystatewinespirits': 'wine and spirits',
#  'sullivanmclaughlin': 'construction',
#  'adamscommunitybank': 'banking',
#  'babsoncollege': 'higher education',
#  'homehealthfoundation': 'hospital & health care',
#  'linneansolutions': 'environmental services',
#  'emc': 'information technology and services',
#  'wachusettfamilyeyecare': 'photography',
#  'valleyopportunitycouncil': 'non-profit organization management',
#  'adcarehospital': 'hospital & health care',
#  'cityofpittsfield': 'government administration',
#  'rutlandnurseriesinc': 'consumer services',
#  'genesismanagementgroup': 'management consulting',
#  'brandeisuniversity': 'higher education',
#  'akamaitechnologies': 'internet',
#  'turtlecreekwinery': 'ranching',
#  'massachusettshightechnologycouncil': 'non-profit organization management',
#  'microsurgicaleyeconsultants': 'medical practice',
#  'luciarestaurant': 'hospitality',
#  'springfieldhousingauthority': 'government administration',
#  'marthasvineyardcommunityservices': 'non-profit organization management',
#  'gibsonsothebysinternationalrealty': 'real estate',
#  'rubinandrudmanllp': 'law practice',
#  'southeasterneconomicdevelopmentseedcorp': 'financial services',
#  'riverviewschool': 'primary/secondary education',
#  'tuftsmedicalcenter': 'hospital & health care',
#  'beverlyhospital': 'hospital & health care',
#  'appliancestandardsawarenessproject': 'public policy',
#  'pingitorefitzpatrickllc': 'law practice',
#  'cetrulollp': 'law practice',
#  'com': 'information technology and services',
#  'newenglandpublicradio': 'media production',
#  'stellarmedicalpublications': 'biotechnology',
#  'korbassociates': 'hospital & health care',
#  'easternfisheriesinc': 'fishery',
#  'putnaminvestments': 'financial services',
#  'thecolonygroup': 'financial services',
#  'acraneconstructionco': 'construction',
#  'wcvbtv': 'broadcast media',
#  'youthbuildusa': 'non-profit organization management',
#  'coghlinelectrical': 'electrical/electronic manufacturing',
#  'townofweymouth': 'civil engineering',
#  'thegoldiegroup': 'wireless',
#  'panamrailways': 'transportation/trucking/railroad',
#  'bridgewaterstateuniversity': 'higher education',
#  'kenneysamspc': 'law practice',
#  'addinc': 'architecture & planning',
#  'bridgewell': 'hospital & health care',
#  'soleproprietor': 'media production',
#  'chestnutinnovationcenter': 'real estate',
#  'llc': 'real estate',
#  'machinistunion': 'paper & forest products',
#  'huntingtontheatrecompany': 'performing arts',
#  'battleshipcove': 'museums and institutions',
#  'bostoncenterforindependentliving': 'non-profit organization management',
#  'samparkcompany': 'real estate',
#  'cafelucia': 'restaurants',
#  'ferriterferriterllc': 'legal services',
#  'massachusettslifesciencescenter': 'government administration',
#  'velir': 'information technology and services',
#  'healthviewservices': 'financial services',
#  'berkshiremuseum': 'museums and institutions',
#  'townofwestborough': 'government administration',
#  'heywoodhealthcare': 'hospital & health care',
#  'marcottelawfirm': 'law practice',
#  'anesthesiaprofessionalsinc': 'hospital & health care',
#  'thecasualgourmet': 'food & beverages',
#  'downtownframinghaminc': 'non-profit organization management',
#  'seniorwholehealth': 'hospital & health care',
#  'everettcreditunion': 'financial services',
#  'cityofnewburyport': 'government administration',
#  'specializedmobileservices': 'hospital & health care',
#  'cityoffitchburg': 'government administration',
#  'orlandoassociates': 'law practice',
#  'intarciatherapeuticsinc': 'biotechnology',
#  'southcoasthealth': 'hospital & health care',
#  'youinc': 'mental health care',
#  'umassmemorialmedicalcenter': 'hospital & health care',
#  'bluespecinc': 'computer software',
#  'intersystems': 'computer software',
#  'duncangalvanizing': 'mechanical or industrial engineering',
#  'pagioinc': 'writing and editing',
#  'firstwind': 'renewables & environment',
#  'zeeveeinc': 'broadcast media',
#  'yankeespirits': 'food & beverages',
#  'newenglandmedicalcenter': 'biotechnology',
#  'townofwalpole': 'government administration',
#  'littlepeoplescollegeinc': 'education management',
#  'leagueschoolofgreaterboston': 'education management',
#  'townofnantucket': 'government administration',
#  'countrybankforsavings': 'banking',
#  'gtiproperties': 'real estate',
#  'ferriterscobborodophelepc': 'law practice',
#  'farmaid': 'non-profit organization management',
#  'lukinc': 'non-profit organization management',
#  'northwindstrategies': 'public relations and communications',
#  'flagshipharboradvisors': 'investment management',
#  'seniorlivingresidences': 'real estate',
#  'fairviewmillwork': 'construction',
#  'stjosephhealthcare': 'hospital & health care',
#  'essgroupinc': 'environmental services',
#  'jjbafaroinc': 'construction',
#  'steffianbradleyarchitects': 'architecture & planning',
#  'atlascontractinginc': 'construction',
#  'massachusettsportauthority': 'airlines/aviation',
#  'orpatentlaw': 'legal services',
#  'willowlaboratories': 'pharmaceuticals',
#  'northeastgasassociation': 'non-profit organization management',
#  'cleengineeringinc': 'civil engineering',
#  'universityofmassachusetts': 'higher education',
#  'strategymattersllc': 'management consulting',
#  'federalreservebankofboston': 'financial services',
#  'lynncommunityhealthcenter': 'hospital & health care',
#  'openthedoor': 'marketing and advertising',
#  'darlingconsultinggroup': 'banking',
#  'wellesleydentalgroup': 'medical practice',
#  'sheehanhealthgroup': 'hospital & health care',
#  'newfirepartners': 'computer software',
#  'victimrightslawcenter': 'legal services',
#  'hirschrobertsweinsteinllp': 'law practice',
#  'epochseniorliving': 'hospital & health care',
#  'snapapp': 'marketing and advertising',
#  'northmarkbank': 'banking',
#  'orainc': 'pharmaceuticals',
#  'keypolymercorporation': 'chemicals',
#  'ahold': 'retail',
#  'solidagofoundation': 'philanthropy',
#  'bostonfirefighterscreditunion': 'financial services',
#  'theimpactseat': 'management consulting',
#  'cambridgecollege': 'higher education',
#  'davidianbrothersfarm': 'insurance',
#  'phillipsacademy': 'primary/secondary education',
#  'newtonwellesleyorthopedicassociates': 'medical practice',
#  'seadarconstruction': 'construction',
#  'denniskburkeinc': 'oil & energy',
#  'quickbase': 'computer software',
#  'qualitybeverage': 'wine and spirits',
#  'butcherbox': 'food & beverages',
#  'synapseenergyeconomics': 'research',
#  'chicopeesavingsbank': 'banking',
#  'lifepathinc': 'individual & family services',
#  'innovationacademycharterschool': 'education management',
#  'lowellgeneralhospital': 'hospital & health care',
#  'riskmanagementadvisors': 'security and investigations',
#  'townofandover': 'government administration',
#  'leefamilyoffice': 'civic & social organization',
#  'monson': 'insurance',
#  'rockwellroofinginc': 'construction',
#  'tuftsuniversityschoolofmedicine': 'higher education',
#  'charlesriverconservancy': 'civic & social organization',
#  'highvistastrategies': 'investment management',
#  'lowellsun': 'newspapers',
#  'lindersinc': 'automotive',
#  'spiritofspringfield': 'entertainment',
#  'stonehambank': 'banking',
#  'ibewlocal': 'telecommunications',
#  'ableassociates': 'staffing and recruiting',
#  'energynewengland': 'oil & energy',
#  'boysgirlsclubofworcester': 'non-profit organization management',
#  'cvpropertiesllc': 'commercial real estate',
#  'chartercommunications': 'marketing and advertising',
#  'clwaterfrontpropertiesllc': 'real estate',
#  'clappazzolapartners': 'events services',
#  'diciccogulmancompany': 'accounting',
#  'massachusettshospitalassociation': 'hospital & health care',
#  'considinefureyllp': 'law practice',
#  'horizonsforhomelesschildren': 'individual & family services',
#  'joinforjustice': 'non-profit organization management',
#  'bostonhousingauthority': 'real estate',
#  'bostondynamics': 'computer software',
#  'cummingsproperties': 'commercial real estate',
#  'riverbendmedicalgroup': 'medical practice',
#  'massinc': 'public policy',
#  'terc': 'research',
#  'americanconsumercreditcounseling': 'financial services',
#  'premierpropertysolutionsllc': 'real estate',
#  'nicholscollege': 'higher education',
#  'greaterlowellhealthalliance': 'health, wellness and fitness',
#  'thebriargroup': 'restaurants',
#  'capecodhealthcare': 'hospital & health care',
#  'pyramidhotelgroup': 'hospitality',
#  'ceresinc': 'capital markets',
#  'blackstonevalleychamberofcommerce': 'non-profit organization management',
#  'northernessexcommunitycollege': 'higher education',
#  'collegeoftheholycross': 'higher education',
#  'financialdevelopmentagency': 'fund-raising',
#  'blackstonevalleytechhs': 'education management',
#  'laheyclinic': 'hospital & health care',
#  'nanigans': 'marketing and advertising',
#  'ngranesesonsinc': 'construction',
#  'framinghamstateuniversity': 'higher education',
#  'srcorporation': 'construction',
#  'scopemedical': 'insurance',
#  'massstatepolice': 'law enforcement',
#  'blueportcommerce': 'internet',
#  'capepointhotel': 'hospitality',
#  'delaneyassociates': 'computer & network security',
#  'holdenadvisors': 'management consulting',
#  'greaterspringfieldconventionvisitorsbureau': 'hospitality',
#  'robpetersentertainment': 'entertainment',
#  'operationable': 'human resources',
#  'mswalkerinc': 'food & beverages',
#  'walthampublicschools': 'primary/secondary education',
#  'townoflittleton': 'government administration',
#  'edwardmkennedyinstitutefortheunitedstatessenate': 'museums and institutions',
#  'thepossibleproject': 'non-profit organization management',
#  'raymurrayinc': 'wholesale',
#  'charlestownworkingtheater': 'performing arts',
#  'charlesriverlaboratories': 'biotechnology',
#  'trivalleyinc': 'nonprofit organization management',
#  'bostonsurveyinc': 'architecture & planning',
#  'newtonwellesleyhospital': 'hospital & health care',
#  'massmutualfinancialgroup': 'financial services',
#  'bdccapital': 'banking',
#  'savetheharborsavethebay': 'non-profit organization management',
#  'bostonteacherresidency': 'education management',
#  'elliottphysicaltherapy': 'hospital & health care',
#  'granitegrouprealtors': 'real estate',
#  'thedowcompanyinc': 'construction',
#  'partnershealthcare': 'management consulting',
#  'primetech': 'building materials',
#  'tintiquinngroverfreypc': 'law practice',
#  'masshousing': 'government administration',
#  'cognexcorporation': 'industrial automation',
#  'riverfrontmarinesportsinc': 'maritime',
#  'captainparkerspub': 'restaurants',
#  'jackconwaycoinc': 'real estate',
#  'cornerstonerealtyconsultants': 'real estate',
#  'toyotaofwatertown': 'automotive',
#  'townoffalmouth': 'government administration',
#  'worlddepot': 'building materials',
#  'leaseportfoliorecoveryservices': 'management consulting',
#  'genesiseldercare': 'financial services',
#  'mgrowth': 'venture capital & private equity',
#  'baycovehumanservices': 'non-profit organization management',
#  'middlesexcommunitycollege': 'higher education',
#  'townofbedford': 'public policy',
#  'leominsterpubliclibrary': 'libraries',
#  'bostonems': 'public safety',
#  'charmmedicalsupply': 'hospital & health care',
#  'marshmclennanagency': 'insurance',
#  'habitatforhumanityofgreaterlowell': 'non-profit organization management',
#  'massfarmbureau': 'farming',
#  'angstromadvanced': 'renewables & environment',
#  'yearup': 'non-profit organization management',
#  'cityofnorthampton': 'information technology and services',
#  'needhamcommunityeducation': 'education management',
#  'thebridgespangroup': 'non-profit organization management',
#  'sturtevantinc': 'machinery',
#  'hillholliday': 'marketing and advertising',
#  'resonantenergy': 'renewables & environment',
#  'centuryadams': 'real estate',
#  'cityofgardner': 'education management',
#  'hammondrealestate': 'real estate',
#  'birdstreetcommunitycenter': 'education management',
#  'allstonbrightoncdc': 'non-profit organization management',
#  'firstamericanmortgagetrust': 'financial services',
#  'greaterbostonchamberofcommerce': 'non-profit organization management',
#  'rudolphfriedmannllp': 'law practice',
#  'contemporarystructuresinc': 'construction',
#  'scalebase': 'computer software',
#  'metzystaqueriallc': 'food & beverages',
#  'mersanatherapeutics': 'biotechnology',
#  'nausetmarine': 'maritime',
#  'cambridgecommunityfellowshipchurch': 'non-profit organization management',
#  'westfieldstateuniversity': 'higher education',
#  'centurybank': 'banking',
#  'murphyhessetoomeylehanellp': 'law practice',
#  'thehyminvestmentgroupllc': 'real estate',
#  'themoynihangroupllc': 'government relations',
#  'aldenterestaurant': 'restaurants',
#  'gaetaenterprisesinc': 'automotive',
#  'ruegiltgroupe': 'retail',
#  'cityofmalden': 'government administration',
#  'northeastarc': 'non-profit organization management',
#  'fullerrosenbergpalmerbeliveaullp': 'legal services',
#  'greatpointproperties': 'real estate',
#  'pinemanorcollege': 'higher education',
#  'massachusettshousinginvestmentcorporation': 'financial services',
#  'greentownlabs': 'renewables & environment',
#  'hubspot': 'internet',
#  'bostonimpactinitiative': 'banking',
#  'mariamitchellassociation': 'museums and institutions',
#  'primr': 'research',
#  'northeasternuniversityschooloflaw': 'legal services',
#  'massachusettspackagestoresassociation': 'non-profit organization management',
#  'adagecapitalmanagement': 'computer & network security',
#  'neighborhoodhealthplan': 'hospital & health care',
#  'fallonambulance': 'public safety',
#  'barrettsingal': 'law practice',
#  'beaconhillconsultinggroup': 'government relations',
#  'worcesterpolytechnicinstitute': 'higher education',
#  'bostonwatersewercommission': 'utilities',
#  'communityservings': 'non-profit organization management',
#  'aubonpain': 'restaurants',
#  'hallamorecorp': 'construction',
#  'ieptechnologies': 'industrial automation',
#  'bostonscientific': 'medical devices',
#  'specialolympicsmassachusetts': 'non-profit organization management',
#  'berkshirebank': 'banking',
#  'tremont': 'food & beverages',
#  'lawyersconcernedforlawyers': 'hospital & health care',
#  'hometapequitypartners': 'financial services',
#  'harwoodproperties': 'real estate',
#  'quansettnurseries': 'design',
#  'currycollege': 'higher education',
#  'maldeninternationaldesigns': 'consumer goods',
#  'massrehabcommission': 'government administration',
#  'countyofbarnstable': 'government administration',
#  'villageautomotivegroup': 'automotive',
#  'local': 'construction',
#  'thecoughlingroup': 'management consulting',
#  'steppingstone': 'professional training & coaching',
#  'annamariacollege': 'higher education',
#  'commonwealthcarealliance': 'hospital & health care',
#  'realtycapitalsecurities': 'financial services',
#  'mutualoilco': nan,
#  'grouponemanagement': 'education management',
#  'mintzlevin': 'law practice',
#  'editbar': 'media production',
#  'abingtonbank': 'banking',
#  'veteransinc': 'individual & family services',
#  'thearielgroup': 'professional training & coaching',
#  'easternequitypartnersllc': 'real estate',
#  'columbiagasofmassachusetts': 'utilities',
#  'centuryadvancedrealty': 'real estate',
#  'gordoncollege': 'higher education',
#  'berkshirevisitorsbureau': 'marketing and advertising',
#  'bostondebateleague': 'non-profit organization management',
#  'deltadentalofmassachusetts': 'insurance',
#  'consigliconstructioncoinc': 'construction',
#  'thehomeforlittlewanderers': 'non-profit organization management',
#  'comforthomecare': 'hospital & health care',
#  'sareptatherapeutics': 'biotechnology',
#  'hannoushjewelers': 'luxury goods & jewelry',
#  'shepleywoodproducts': 'building materials',
#  'berkshirecommunitycollege': 'higher education',
#  'scholarsstrategynetwork': 'public policy',
#  'bochtoyota': 'automotive',
#  'originproductdevelopment': 'design',
#  'holbrookcooperativebank': 'banking',
#  'regiscollege': 'law enforcement',
#  'arnoldworldwide': 'marketing and advertising',
#  'thecambridgeschoolofweston': 'primary/secondary education',
#  'cityofnewbedford': 'government administration',
#  'massachusettsconventioncenterauthority': 'events services',
#  'gracechapel': 'religious institutions',
#  'wachusettbrewingcompany': 'food & beverages',
#  'sbliofmassachusetts': 'insurance',
#  'northshoremedicalcenter': 'hospital & health care',
#  'danagroupassociates': 'mental health care',
#  'tewksburycountryclub': 'hospitality',
#  'framinghampublicschools': 'government administration',
#  'keswickconsulting': 'government relations',
#  'tewksburyphysicaltherapy': 'health, wellness and fitness',
#  'climatexchange': 'research',
#  'highpointtreatmentcenter': 'mental health care',
#  'massachusettsdentalsociety': 'non-profit organization management',
#  'coreinvestmentsinc': 'real estate',
#  'cityofworcester': 'government administration',
#  'clavisinsight': 'computer software',
#  'wellforce': 'hospital & health care',
#  'ironwoodpharmaceuticals': 'pharmaceuticals',
#  'curaspanhealthgroup': 'information technology and services',
#  'remaxrightchoice': 'real estate',
#  'parkerkeoughllp': 'law practice',
#  'kronos': 'computer software',
#  'legalseafoods': 'restaurants',
#  'casneredwardsllp': 'law practice',
#  'greaterbostonlegalservices': 'legal services',
#  'almadelmarcharterschool': 'education management',
#  'professionalstaffinggroup': 'staffing and recruiting',
#  'fallriverhousingauthority': 'facilities services',
#  'shaevelkrems': 'law practice',
#  'ihrsa': 'health, wellness and fitness',
#  'gordonbrothersgroup': 'financial services',
#  'bostonharbornow': 'environmental services',
#  'cambridgehousingauthority': 'government administration',
#  'childrenshealthwatch': 'research',
#  'broadinstitute': 'research',
#  'bostonsportsshouldercenter': 'medical practice',
#  'fourstarfarms': 'farming',
#  'kaplanconstruction': 'construction',
#  'chelseadistrictcourt': 'government administration',
#  'conservationservicesgroup': 'environmental services',
#  'bluewavesolar': 'renewables & environment',
#  'thebrennangroupinc': 'government relations',
#  ...}

# %%
companies_list_clean.shape
# Out:
# (67306,)

# %%
employer_dict = {}
for employer in match_set:
    for company in companies_list_clean:
        if fuzz.ratio(employer, company) >= 85:
            employer_dict[employer] = company

# %%
employer_dict_list = list(employer_dict.keys())
company_dict_list = list(employer_dict.values())

# %%
len(employer_dict_list)
# Out:
# 5337

# %%
len(company_dict_list)
# Out:
# 5337

# %%
def com_search(name):
    if name in employer_dict.keys():
        industry = df_companies[df_companies['Company_clean'] == employer_dict[name]]['Industry'].values[0]
        return industry

# %%
df_contribuion['Industry_new'] = df_contribuion['Employer_clean'].apply(com_search)

# %%
df_contribuion['Industry_new'].value_counts().sum()
# Out:
# 22383

# %%
df_contribuion.drop(columns=['Employer_clean'], inplace=True)

# %%
df_contribuion.shape
# Out:
# (118461, 24)

# %%
df_contribuion.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1               Address  Amount       City  \
# 0           0          7373  270 S. Common Street   500.0       Lynn
# 1           1          7374       186 Perkins Row   250.0  Topsfield
# 2           2          7634          11 Lake Ave.    25.0       Lynn
# 3           3          7635         7 William St.    50.0       Lynn
# 4           4          7636      20 Bulfinch Ter.    50.0       Lynn
#
#    Contributor_ID Contributor_Type        Date             Employer  \
# 0             NaN       Individual  2015-01-01  McGrath Enterprises
# 1             NaN       Individual  2015-01-15                 Self
# 2             NaN       Individual  2015-03-02                  NaN
# 3             NaN       Individual  2015-03-02                  NaN
# 4             NaN       Individual  2015-03-02                  NaN
#
#   First_Name  ... Occupation  Principal_Officer Report_ID  State    Zip  \
# 0    Patrick  ...  Developer                NaN    217037     MA  01905
# 1     Thomas  ...   Attorney                NaN    217037     MA  01983
# 2    Loretta  ...        NaN                NaN    217124     MA  10904
# 3    Stephen  ...        NaN                NaN    217124     MA  01904
# 4  Ann Marie  ...        NaN                NaN    217124     MA  01902
#
#           Donor_Name    Industry  PAC Lobbyist  \
# 0    PATRICK MCGRATH         NaN  NaN    False
# 1     THOMAS DEMAKIS  Healthcare  NaN    False
# 2  LORETTA O'DONNELL         NaN  NaN    False
# 3    STEPHEN SPENCER         NaN  NaN    False
# 4  ANN MARIE LEONARD         NaN  NaN    False
#
#                        Industry_new
# 0                              None
# 1  professional training & coaching
# 2                              None
# 3                              None
# 4                              None
#
# [5 rows x 24 columns]

# %%
df_contribuion.to_csv('data/contribution_experiment.csv')
